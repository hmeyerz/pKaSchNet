# %%
import torch
import numpy as np
import glob
p=glob.glob("../../parallel*.pt")
for c in p[0:]:
    print(c)
    a=torch.load(c, map_location=torch.device('cpu'))
    c=a["config"]
    
    plosses=a["train_history"]
    vlosses=a["val_history"]
    from matplotlib import pyplot as plt
    #plt.plot(np.array([plosses]).flatten())
    #plt.show()
    #plt.plot(np.array([vlosses]).flatten())

    #plt.title(f"nhr")
    #plt.show()


    from matplotlib import pyplot as plt
    plt.plot(np.array([plosses]).flatten())
    #plt.show()
    plt.plot(np.array([vlosses]).flatten(), label="val",alpha=0.7)
    #plt.ylim(0,0.6)

    plt.title(("num_ins:", c["dataset"][1],"dim, depth, numrbf:",c["dim"],c["depth"],c["basis"],"numtokens:",c["num edge and global tokens"],"drop:",c["dropout"]))
    plt.legend()
    plt.show()
# Out:
# ../../parallel_20250713_220052-checkpoint_20250713_220059.pt
# ../../parallel_20250713_220206-checkpoint_20250713_220233.pt
# ../../parallel_20250713_220432-checkpoint_20250713_220507.pt
# ../../parallel_20250713_220546-checkpoint_20250713_220716.pt
# ../../parallel_20250713_220816-checkpoint_20250713_220845.pt
# ../../parallel_20250713_221303-checkpoint_20250713_221333.pt
# ../../parallel_20250713_221604-checkpoint_20250713_221710.pt
# ../../parallel_20250713_221838-checkpoint_20250713_221943.pt
# ../../parallel_20250713_222039-checkpoint_20250713_222145.pt
# ../../parallel_20250713_222411-checkpoint_20250713_222523.pt
# ../../parallel_20250713_222857-checkpoint_20250713_223011.pt
# ../../parallel_20250713_223552-checkpoint_20250713_223752.pt
# ../../parallel_20250713_223927-checkpoint_20250713_224315.pt
# ../../parallel_20250713_225654-checkpoint_20250713_230316.pt
# ../../parallel_20250713_230530-checkpoint_20250713_232903.pt
# ../../parallel_20250713_232941-checkpoint_20250714_000426.pt
