# %%
import torch
import numpy as np
import glob
p=glob.glob("/home/jrhoernschemeyer/Desktop/data_prep/test_2025071*.pt")
for cc in p[14:]:
    #print(cc)
    a=torch.load(cc, map_location=torch.device('cpu'))
    c=a["config"]
    
    plosses=a["train_history"]
    vlosses=a["val_history"]
    from matplotlib import pyplot as plt
    #plt.plot(np.array([plosses]).flatten())
    #plt.show()
    #plt.plot(np.array([vlosses]).flatten())

    #plt.title(f"nhr")
    #plt.show()


    from matplotlib import pyplot as plt
    plt.plot(np.array([plosses]).flatten(),"--",alpha=0.8)
    #plt.show()
    plt.plot(np.array([vlosses]).flatten(), label=cc.split("point_")[1],color="black")
    #plt.ylim(0,0.6)

    plt.title((f"{len(p[14:])} models","dim, depth, rbf:",c["dim"],c["depth"],c["basis"],"p:",c["params"],"drop:",c["dropout"]))
    #plt.legend()
    #plt.show()

# %%
"""(jessi) bgn1005:~ $ python nhr_new998.py 
Whole model          : 32,510
{'runid': '20250716_193407', 'num_nbrs': 100, 'num_nbrs_egnn': 11, 'learning_rate': [0.001], 'dataset': ('1000inputs/*.npz', 700, 300), 'epochs': 200, 'dim': 12, 'depth': 2, 'basis': 8, 'hidden_dim': 4, 'num_heads': 20, 'dropout': [0.03, 0.03], 'rbf cutoff': 20.0, 'loss': L1Loss(), 'params': 32510}
Epoch   0 | train L1 = 0.9334
              |  val L1 = 0.7204
Epoch   1 | train L1 = 0.7227
              |  val L1 = 0.6671
Epoch   2 | train L1 = 0.6782
              |  val L1 = 0.6785
Epoch   3 | train L1 = 0.6428
              |  val L1 = 0.6079
Epoch   4 | train L1 = 0.6211
              |  val L1 = 0.5871
Epoch   5 | train L1 = 0.5994
              |  val L1 = 0.5748
Epoch   6 | train L1 = 0.5835
              |  val L1 = 0.5644
Epoch   7 | train L1 = 0.5770
              |  val L1 = 0.5706
Epoch   8 | train L1 = 0.5672
              |  val L1 = 0.5496
Epoch   9 | train L1 = 0.5586
              |  val L1 = 0.5923
Epoch  10 | train L1 = 0.5534
              |  val L1 = 0.5697
Epoch  11 | train L1 = 0.5450
              |  val L1 = 0.5413
Epoch  12 | train L1 = 0.5387
              |  val L1 = 0.5213
Epoch  13 | train L1 = 0.5301
              |  val L1 = 0.5133
Epoch  14 | train L1 = 0.5260
              |  val L1 = 0.5118
Epoch  15 | train L1 = 0.5205
              |  val L1 = 0.5172
Epoch  16 | train L1 = 0.5181
              |  val L1 = 0.5061
Epoch  17 | train L1 = 0.5117
              |  val L1 = 0.5029
Epoch  18 | train L1 = 0.5057
              |  val L1 = 0.4946
Epoch  19 | train L1 = 0.5031
              |  val L1 = 0.4919
Epoch  20 | train L1 = 0.4983
              |  val L1 = 0.4961
Epoch  21 | train L1 = 0.4955
              |  val L1 = 0.4802
Epoch  22 | train L1 = 0.4896
              |  val L1 = 0.4790
Epoch  23 | train L1 = 0.4872
              |  val L1 = 0.5022
Epoch  24 | train L1 = 0.4781
              |  val L1 = 0.4712
Epoch  25 | train L1 = 0.4761
              |  val L1 = 0.4900
Epoch  26 | train L1 = 0.4749
              |  val L1 = 0.4823
Epoch  27 | train L1 = 0.4749
              |  val L1 = 0.4664
Epoch  28 | train L1 = 0.4726
              |  val L1 = 0.4901
Epoch  29 | train L1 = 0.4674
              |  val L1 = 0.4785
Epoch  30 | train L1 = 0.4672
              |  val L1 = 0.4764
Epoch  31 | train L1 = 0.4599
              |  val L1 = 0.4550
Epoch  32 | train L1 = 0.4556
              |  val L1 = 0.4493
Epoch  33 | train L1 = 0.4553
              |  val L1 = 0.4437
Epoch  34 | train L1 = 0.4454
              |  val L1 = 0.4539
Epoch  35 | train L1 = 0.4469
              |  val L1 = 0.4402
Epoch  36 | train L1 = 0.4426
              |  val L1 = 0.4391
Epoch  37 | train L1 = 0.4413
              |  val L1 = 0.4525
Epoch  38 | train L1 = 0.4362
              |  val L1 = 0.4521
Epoch  39 | train L1 = 0.4352
              |  val L1 = 0.4336
Epoch  40 | train L1 = 0.4282
              |  val L1 = 0.4269
Epoch  41 | train L1 = 0.4282
              |  val L1 = 0.4341
Epoch  42 | train L1 = 0.4243
              |  val L1 = 0.4284
Epoch  43 | train L1 = 0.4209
              |  val L1 = 0.4213
Epoch  44 | train L1 = 0.4206
              |  val L1 = 0.4188
Epoch  45 | train L1 = 0.4195
              |  val L1 = 0.4288
Epoch  46 | train L1 = 0.4152
              |  val L1 = 0.4405
Epoch  47 | train L1 = 0.4151
              |  val L1 = 0.4154
Epoch  48 | train L1 = 0.4117
              |  val L1 = 0.4160
Epoch  49 | train L1 = 0.4102
              |  val L1 = 0.4093
Epoch  50 | train L1 = 0.4079
              |  val L1 = 0.4202
Epoch  51 | train L1 = 0.4090
              |  val L1 = 0.4473
Epoch  52 | train L1 = 0.4100
              |  val L1 = 0.4145
Epoch  53 | train L1 = 0.4021
              |  val L1 = 0.4174
Epoch  54 | train L1 = 0.4021
              |  val L1 = 0.4354
Epoch  55 | train L1 = 0.4022
              |  val L1 = 0.4051
Epoch  56 | train L1 = 0.3995
              |  val L1 = 0.4130
Epoch  57 | train L1 = 0.3979
              |  val L1 = 0.4240
Epoch  58 | train L1 = 0.3970
              |  val L1 = 0.4240
Epoch  59 | train L1 = 0.3967
              |  val L1 = 0.4209
Epoch  60 | train L1 = 0.3936
              |  val L1 = 0.4081
Epoch  61 | train L1 = 0.3933
              |  val L1 = 0.4074
Epoch  62 | train L1 = 0.3910
              |  val L1 = 0.4077
Epoch  63 | train L1 = 0.3896
              |  val L1 = 0.4014
Epoch  64 | train L1 = 0.3867
              |  val L1 = 0.3968
Epoch  65 | train L1 = 0.3868
              |  val L1 = 0.4086
Epoch  66 | train L1 = 0.3855
              |  val L1 = 0.4105
Epoch  67 | train L1 = 0.3843
              |  val L1 = 0.4049
Epoch  68 | train L1 = 0.3852
              |  val L1 = 0.4081
Epoch  69 | train L1 = 0.3824
              |  val L1 = 0.3966
Epoch  70 | train L1 = 0.3815
              |  val L1 = 0.4025
Epoch  71 | train L1 = 0.3811
              |  val L1 = 0.4002
Epoch  72 | train L1 = 0.3786
              |  val L1 = 0.3935
Epoch  73 | train L1 = 0.3775
              |  val L1 = 0.3925
Epoch  74 | train L1 = 0.3782
              |  val L1 = 0.3967
Epoch  75 | train L1 = 0.3783
              |  val L1 = 0.3981
Epoch  76 | train L1 = 0.3760
              |  val L1 = 0.3913
Epoch  77 | train L1 = 0.3716
              |  val L1 = 0.4134
Epoch  78 | train L1 = 0.3735
              |  val L1 = 0.3986
Epoch  79 | train L1 = 0.3710
              |  val L1 = 0.3885
Epoch  80 | train L1 = 0.3710
              |  val L1 = 0.3894
Epoch  81 | train L1 = 0.3711
              |  val L1 = 0.3885
Epoch  82 | train L1 = 0.3705
              |  val L1 = 0.4001
Epoch  83 | train L1 = 0.3698
              |  val L1 = 0.3838
Epoch  84 | train L1 = 0.3673
              |  val L1 = 0.3954
Epoch  85 | train L1 = 0.3684
              |  val L1 = 0.3899
Epoch  86 | train L1 = 0.3651
              |  val L1 = 0.3905
Epoch  87 | train L1 = 0.3665
              |  val L1 = 0.3832
Epoch  88 | train L1 = 0.3652
              |  val L1 = 0.3824
Epoch  89 | train L1 = 0.3658
              |  val L1 = 0.3921
Epoch  90 | train L1 = 0.3650
              |  val L1 = 0.3842
Epoch  91 | train L1 = 0.3641
              |  val L1 = 0.3917
Epoch  92 | train L1 = 0.3638
              |  val L1 = 0.3818
Epoch  93 | train L1 = 0.3611
              |  val L1 = 0.3887
Epoch  94 | train L1 = 0.3601
              |  val L1 = 0.3954
Epoch  95 | train L1 = 0.3597
              |  val L1 = 0.3891
Epoch  96 | train L1 = 0.3607
              |  val L1 = 0.3871
Epoch  97 | train L1 = 0.3610
              |  val L1 = 0.3938
Epoch  98 | train L1 = 0.3592
              |  val L1 = 0.3916
Epoch  99 | train L1 = 0.3546
              |  val L1 = 0.3793
Epoch 100 | train L1 = 0.3558
              |  val L1 = 0.3885
Epoch 101 | train L1 = 0.3570
              |  val L1 = 0.3801
Epoch 102 | train L1 = 0.3558
              |  val L1 = 0.3795
Epoch 103 | train L1 = 0.3565
              |  val L1 = 0.3802
Epoch 104 | train L1 = 0.3518
              |  val L1 = 0.3801
Epoch 105 | train L1 = 0.3520
              |  val L1 = 0.3891
Epoch 106 | train L1 = 0.3524
              |  val L1 = 0.3816
Epoch 107 | train L1 = 0.3530
              |  val L1 = 0.3793
Epoch 108 | train L1 = 0.3535
              |  val L1 = 0.3753
Epoch 109 | train L1 = 0.3481
              |  val L1 = 0.3823
Epoch 110 | train L1 = 0.3517
              |  val L1 = 0.3840
Epoch 111 | train L1 = 0.3520
              |  val L1 = 0.3813
Epoch 112 | train L1 = 0.3508
              |  val L1 = 0.3817
Epoch 113 | train L1 = 0.3517
              |  val L1 = 0.3769
Epoch 114 | train L1 = 0.3487
              |  val L1 = 0.3775
Epoch 115 | train L1 = 0.3461
              |  val L1 = 0.3780
Epoch 116 | train L1 = 0.3460
              |  val L1 = 0.3761
Epoch 117 | train L1 = 0.3472
              |  val L1 = 0.3737
Epoch 118 | train L1 = 0.3470
              |  val L1 = 0.3797
Epoch 119 | train L1 = 0.3482
              |  val L1 = 0.3858
Epoch 120 | train L1 = 0.3462
              |  val L1 = 0.3744
Epoch 121 | train L1 = 0.3447
              |  val L1 = 0.3789
Epoch 122 | train L1 = 0.3458
              |  val L1 = 0.3870
Epoch 123 | train L1 = 0.3443
              |  val L1 = 0.3854
Epoch 124 | train L1 = 0.3449
              |  val L1 = 0.3761
Epoch 125 | train L1 = 0.3441
              |  val L1 = 0.3788
Epoch 126 | train L1 = 0.3426
              |  val L1 = 0.3737
Epoch 127 | train L1 = 0.3422
              |  val L1 = 0.3923
Epoch 128 | train L1 = 0.3436
              |  val L1 = 0.3754
Epoch 129 | train L1 = 0.3398
              |  val L1 = 0.3707
Epoch 130 | train L1 = 0.3413
              |  val L1 = 0.3808
Epoch 131 | train L1 = 0.3406
              |  val L1 = 0.3767
Epoch 132 | train L1 = 0.3401
              |  val L1 = 0.3736
Epoch 133 | train L1 = 0.3402
              |  val L1 = 0.3802
Epoch 134 | train L1 = 0.3397
              |  val L1 = 0.3805
Epoch 135 | train L1 = 0.3395
              |  val L1 = 0.3712
Epoch 136 | train L1 = 0.3377
              |  val L1 = 0.3780
Epoch 137 | train L1 = 0.3370
              |  val L1 = 0.3837
Epoch 138 | train L1 = 0.3381
              |  val L1 = 0.3720
Epoch 139 | train L1 = 0.3372
              |  val L1 = 0.3813
Epoch 140 | train L1 = 0.3375
              |  val L1 = 0.3700
Epoch 141 | train L1 = 0.3355
              |  val L1 = 0.3691
Epoch 142 | train L1 = 0.3367
              |  val L1 = 0.3863
Epoch 143 | train L1 = 0.3353
              |  val L1 = 0.3756
Epoch 144 | train L1 = 0.3364
              |  val L1 = 0.3687
Epoch 145 | train L1 = 0.3335
              |  val L1 = 0.3815
Epoch 146 | train L1 = 0.3359
              |  val L1 = 0.3737
Epoch 147 | train L1 = 0.3363
              |  val L1 = 0.3711
Epoch 148 | train L1 = 0.3355
              |  val L1 = 0.3698
Epoch 149 | train L1 = 0.3354
              |  val L1 = 0.3711
Epoch 150 | train L1 = 0.3326
              |  val L1 = 0.3710
Epoch 151 | train L1 = 0.3324
              |  val L1 = 0.3720
Epoch 152 | train L1 = 0.3334
              |  val L1 = 0.3691
Epoch 153 | train L1 = 0.3324
              |  val L1 = 0.3732
Epoch 154 | train L1 = 0.3318
              |  val L1 = 0.3681
Epoch 155 | train L1 = 0.3326
              |  val L1 = 0.3692
Epoch 156 | train L1 = 0.3298
              |  val L1 = 0.3731
Epoch 157 | train L1 = 0.3325
              |  val L1 = 0.3658
Epoch 158 | train L1 = 0.3316
              |  val L1 = 0.3784
Epoch 159 | train L1 = 0.3328
              |  val L1 = 0.3822
Epoch 160 | train L1 = 0.3319
              |  val L1 = 0.3737
Epoch 161 | train L1 = 0.3295
              |  val L1 = 0.3956
Epoch 162 | train L1 = 0.3307
              |  val L1 = 0.3695
Epoch 163 | train L1 = 0.3303
              |  val L1 = 0.3685
Epoch 164 | train L1 = 0.3287
              |  val L1 = 0.3698
Epoch 165 | train L1 = 0.3296
              |  val L1 = 0.3707
Epoch 166 | train L1 = 0.3289
              |  val L1 = 0.3677
Epoch 167 | train L1 = 0.3283
              |  val L1 = 0.3781
Epoch 168 | train L1 = 0.3288
              |  val L1 = 0.3681
Epoch 169 | train L1 = 0.3290
              |  val L1 = 0.3666
Epoch 170 | train L1 = 0.3279
              |  val L1 = 0.3801
Epoch 171 | train L1 = 0.3296
              |  val L1 = 0.3673
Epoch 172 | train L1 = 0.3265
              |  val L1 = 0.3745
Epoch 173 | train L1 = 0.3265
              |  val L1 = 0.3676
Epoch 174 | train L1 = 0.3252
              |  val L1 = 0.3677
Epoch 175 | train L1 = 0.3260
              |  val L1 = 0.3672
Epoch 176 | train L1 = 0.3263
              |  val L1 = 0.3737
Epoch 177 | train L1 = 0.3255
              |  val L1 = 0.3672
Epoch 178 | train L1 = 0.3252
              |  val L1 = 0.3693
Epoch 179 | train L1 = 0.3244
              |  val L1 = 0.3672
Epoch 180 | train L1 = 0.3249
              |  val L1 = 0.3729
Epoch 181 | train L1 = 0.3253
              |  val L1 = 0.3667
Epoch 182 | train L1 = 0.3244
              |  val L1 = 0.3708
Epoch 183 | train L1 = 0.3244
              |  val L1 = 0.3671
Epoch 184 | train L1 = 0.3249
              |  val L1 = 0.3747
Epoch 185 | train L1 = 0.3263
              |  val L1 = 0.3695
Epoch 186 | train L1 = 0.3241
              |  val L1 = 0.3740
Epoch 187 | train L1 = 0.3225
              |  val L1 = 0.3667
Epoch 188 | train L1 = 0.3225
              |  val L1 = 0.3746
Epoch 189 | train L1 = 0.3221
              |  val L1 = 0.3722
Epoch 190 | train L1 = 0.3223
              |  val L1 = 0.3710
Epoch 191 | train L1 = 0.3217
              |  val L1 = 0.3640
Epoch 192 | train L1 = 0.3225
              |  val L1 = 0.3688
Epoch 193 | train L1 = 0.3212
              |  val L1 = 0.3754
Epoch 194 | train L1 = 0.3211
              |  val L1 = 0.3676
Epoch 195 | train L1 = 0.3212
              |  val L1 = 0.3685
Epoch 196 | train L1 = 0.3203
              |  val L1 = 0.3748
Epoch 197 | train L1 = 0.3210
              |  val L1 = 0.3662
Epoch 198 | train L1 = 0.3200
              |  val L1 = 0.3648
Epoch 199 | train L1 = 0.3201
              |  val L1 = 0.3654
Saved checkpoint_20250716_210043.pt (86.6 min) 86.62409465312957
(jessi) bgn1005:~ $ """
# Out:
# "(jessi) bgn1005:~ $ python nhr_new998.py \nWhole model          : 32,510\n{'runid': '20250716_193407', 'num_nbrs': 100, 'num_nbrs_egnn': 11, 'learning_rate': [0.001], 'dataset': ('1000inputs/*.npz', 700, 300), 'epochs': 200, 'dim': 12, 'depth': 2, 'basis': 8, 'hidden_dim': 4, 'num_heads': 20, 'dropout': [0.03, 0.03], 'rbf cutoff': 20.0, 'loss': L1Loss(), 'params': 32510}\nEpoch   0 | train L1 = 0.9334\n              |  val L1 = 0.7204\nEpoch   1 | train L1 = 0.7227\n              |  val L1 = 0.6671\nEpoch   2 | train L1 = 0.6782\n              |  val L1 = 0.6785\nEpoch   3 | train L1 = 0.6428\n              |  val L1 = 0.6079\nEpoch   4 | train L1 = 0.6211\n              |  val L1 = 0.5871\nEpoch   5 | train L1 = 0.5994\n              |  val L1 = 0.5748\nEpoch   6 | train L1 = 0.5835\n              |  val L1 = 0.5644\nEpoch   7 | train L1 = 0.5770\n              |  val L1 = 0.5706\nEpoch   8 | train L1 = 0.5672\n              |  val L1 = 0.5496\nEpoch   9 | train L1 = 0.5586\n      
# ...
