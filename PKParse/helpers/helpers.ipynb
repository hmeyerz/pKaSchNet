# %%
import pdbfixer
from openmm.app import PDBFile
def fix_pdb(self,pdb):
    """non executable in this dir
    gets og residue mapping. then pdbfixes, which adds missing residues in accordance with the sequence, adds hydrogens at pH 7.
    and then removes alt conforms (conformB)"""
    
    # !wget https://files.rcsb.org/download/{pdb}.pdb
    fixer =pdbfixer.PDBFixer(f"{pdb}.pdb")
    fixer.findNonstandardResidues()
    fixer.findMissingResidues()
    fixer.findMissingAtoms()
    fixer.replaceNonstandardResidues()
    fixer.addMissingAtoms()
    #PDBFile.writeFile(fixer.topology, fixer.positions, f"{path}altstructs/{pdb}-noH.pdb")
    fixer.addMissingHydrogens(pH=7.0)
    PDBFile.writeFile(fixer.topology, fixer.positions, f"{pdb}f.pdb")

# %% [markdown]
# colab

# %% [markdown]
# !pip install condacolab
# import condacolab
# condacolab.install()
# !conda install pdbfixer
# !pip install egnn-pytorch
# from google.colab import drive
# from google.colab import files
# drive.mount('/content/drive')

# %% [markdown]
# chat parsed partial charges from rtf files which were on pkaschnet from charm from jesse, ages ago. still in nonmain branches on github

# %% [markdown]
# residues = {
#     "ALA": {
#         "N":   -0.47,
#         "HN":   0.31,
#         "CA":   0.07,
#         "HA":   0.09,
#         "CB":  -0.27,
#         "HB1":  0.09,
#         "HB2":  0.09,
#         "HB3":  0.09,
#         "C":    0.51,
#         "O":   -0.51
#     },
#     "ARG": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":   -0.18,
#         "HG1":   0.09,
#         "HG2":   0.09,
#         "CD":    0.20,
#         "HD1":   0.09,
#         "HD2":   0.09,
#         "NE":   -0.70,
#         "HE":    0.44,
#         "CZ":    0.64,
#         "NH1":  -0.80,
#         "HH11":  0.46,
#         "HH12":  0.46,
#         "NH2":  -0.80,
#         "HH21":  0.46,
#         "HH22":  0.46,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "ASN": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":    0.55,
#         "OD1":  -0.55,
#         "ND2":  -0.62,
#         "HD21":  0.32,
#         "HD22":  0.30,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "ASP": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.28,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":    0.62,
#         "OD1":  -0.76,
#         "OD2":  -0.76,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "CYS": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.11,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "SG":   -0.23,
#         "HG1":   0.16,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "GLN": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":   -0.18,
#         "HG1":   0.09,
#         "HG2":   0.09,
#         "CD":    0.55,
#         "OE1":  -0.55,
#         "NE2":  -0.62,
#         "HE21":  0.32,
#         "HE22":  0.30,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "GLU": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":   -0.28,
#         "HG1":   0.09,
#         "HG2":   0.09,
#         "CD":    0.62,
#         "OE1":  -0.76,
#         "OE2":  -0.76,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "GLY": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":   -0.02,
#         "HA1":   0.09,
#         "HA2":   0.09,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "HSD": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.09,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "ND1":  -0.36,
#         "HD1":   0.32,
#         "CG":   -0.05,
#         "CE1":   0.25,
#         "HE1":   0.13,
#         "NE2":  -0.70,
#         "CD2":   0.22,
#         "HD2":   0.10,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "HSE": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.08,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "ND1":  -0.70,
#         "CG":    0.22,
#         "CE1":   0.25,
#         "HE1":   0.13,
#         "NE2":  -0.36,
#         "HE2":   0.32,
#         "CD2":  -0.05,
#         "HD2":   0.09,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "HSP": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.05,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CD2":   0.19,
#         "HD2":   0.13,
#         "CG":    0.19,
#         "NE2":  -0.51,
#         "HE2":   0.44,
#         "ND1":  -0.51,
#         "HD1":   0.44,
#         "CE1":   0.32,
#         "HE1":   0.18,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "ILE": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.09,
#         "HB":    0.09,
#         "CG2":  -0.27,
#         "HG21":  0.09,
#         "HG22":  0.09,
#         "HG23":  0.09,
#         "CG1":  -0.18,
#         "HG11":  0.09,
#         "HG12":  0.09,
#         "CD":   -0.27,
#         "HD1":   0.09,
#         "HD2":   0.09,
#         "HD3":   0.09,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "LEU": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":   -0.09,
#         "HG":    0.09,
#         "CD1":  -0.27,
#         "HD11":  0.09,
#         "HD12":  0.09,
#         "HD13":  0.09,
#         "CD2":  -0.27,
#         "HD21":  0.09,
#         "HD22":  0.09,
#         "HD23":  0.09,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "LYS": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":   -0.18,
#         "HG1":   0.09,
#         "HG2":   0.09,
#         "CD":   -0.18,
#         "HD1":   0.09,
#         "HD2":   0.09,
#         "CE":    0.21,
#         "HE1":   0.05,
#         "HE2":   0.05,
#         "NZ":   -0.30,
#         "HZ1":   0.33,
#         "HZ2":   0.33,
#         "HZ3":   0.33,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "MET": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":   -0.14,
#         "HG1":   0.09,
#         "HG2":   0.09,
#         "SD":   -0.09,
#         "CE":   -0.22,
#         "HE1":   0.09,
#         "HE2":   0.09,
#         "HE3":   0.09,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "PHE": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":    0.00,
#         "CD1":  -0.115,
#         "HD1":   0.115,
#         "CE1":  -0.115,
#         "HE1":   0.115,
#         "CZ":  -0.115,
#         "HZ":   0.115,
#         "CD2":  -0.115,
#         "HD2":   0.115,
#         "CE2":  -0.115,
#         "HE2":   0.115,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "PRO": {
#         "N":   -0.29,
#         "CD":   0.00,
#         "CA":   0.02,
#         "HA":   0.09,
#         "CB":  -0.18,
#         "HB1":  0.09,
#         "HB2":  0.09,
#         "CG":  -0.18,
#         "HG1":  0.09,
#         "HG2":  0.09,
#         "C":    0.51,
#         "O":   -0.51
#     },
#     "SER": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":    0.05,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "OG":   -0.66,
#         "HG1":   0.43,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "THR": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":    0.14,
#         "HB":    0.09,
#         "OG1":  -0.66,
#         "HG1":   0.43,
#         "CG2":  -0.27,
#         "HG21":  0.09,
#         "HG22":  0.09,
#         "HG23":  0.09,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "TRP": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":   -0.03,
#         "CD1":  -0.15,
#         "HD1":   0.22,
#         "NE1":  -0.51,
#         "HE1":   0.37,
#         "CE2":   0.24,
#         "CD2":   0.11,
#         "CE3":  -0.25,
#         "HE3":   0.17,
#         "CZ3":  -0.20,
#         "HZ3":   0.14,
#         "CZ2":  -0.27,
#         "HZ2":   0.16,
#         "CH2":  -0.14,
#         "HH2":   0.14,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "TYR": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.18,
#         "HB1":   0.09,
#         "HB2":   0.09,
#         "CG":    0.00,
#         "CD1":  -0.115,
#         "HD1":   0.115,
#         "CE1":  -0.115,
#         "HE1":   0.115,
#         "CZ":    0.11,
#         "OH":   -0.54,
#         "HH":    0.43,
#         "CD2":  -0.115,
#         "HD2":   0.115,
#         "CE2":  -0.115,
#         "HE2":   0.115,
#         "C":     0.51,
#         "O":    -0.51
#     },
#     "VAL": {
#         "N":    -0.47,
#         "HN":    0.31,
#         "CA":    0.07,
#         "HA":    0.09,
#         "CB":   -0.09,
#         "HB":    0.09,
#         "CG1":  -0.27,
#         "HG11":  0.09,
#         "HG12":  0.09,
#         "HG13":  0.09,
#         "CG2":  -0.27,
#         "HG21":  0.09,
#         "HG22":  0.09,
#         "HG23":  0.09,
#         "C":     0.51,
#         "O":    -0.51
#     }
# }

# %%
import numpy as np
#b"HOH" in 
a=np.load("data/ligands.npz")["data"]

#https://project-gemmi.github.io/periodic-table/
