# %%
from egnn_pytorch import EGNN_Network

import torch.nn as nn
import numpy as np
import random
import torch.nn.functional as F
import itertools

import torch
from matplotlib import pyplot as plt
import glob

from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
from collections import defaultdict
import dask.dataframe as dd

charges = {'HIS': 1, 'LYS': 1,
           'ASP': -1, 'GLU': -1,  # carboxylate
           'CYS': 0,
           'TYR': 0}   # thiol and phenol prot

cations = {'HIS': ("HD1", "HD2", "HE1", "HE2"),
        'ASP':None,
        "LYS":("HZ1", "HZ2","HZ3"),
        "TYR":"HH",
        "GLU":None,
        "CYS":'HG',
        "ARG": ("HE11","HE12", "HE21", "HE22"),
        "THR":"HG1",
        "SER":"HG",
        "TRP":"HE1"}


anions = {"HIS":("ND1", "ND2"),
          "ASP":("OD1","OD2"),
          "LYS":"NZ",
          "TYR":"OH",
          "GLU":("OE1", "OE2"),
          "CYS":"SG",
          "ARG": ("NE1","NE2"),
          "THR":"OG1",
          "SER":"OG",
          "TRP":"NE1"}

prot = charges.keys()

directory = "/home/jrhoernschemeyer/Desktop/thesis/"


def load_pdb(path):
    solvents, counter = {}, 0
    with open(path, "r") as f:
        resis, xs, counter = {}, [], 0
        for line in f:
            L = line.split()

            if line.startswith("ATOM"):
                resname, atomname = L[3], L[2]
                if resname in charges.keys():
                    resname = resname + str(L[5]) + L[4]

                    if resname in resis:
                        resis[resname][f"{atomname} {counter}"] = (float(L[6]), float(L[7]), float(L[8]))
                        counter += 1
                    else:
                        resis[resname] = {f"{atomname} {counter}": (float(L[6]), float(L[7]), float(L[8]))}
                        counter += 1

                else:  # resname in noprot
                    resname, atomname = L[3], L[2]
                    xs.append((float(L[6]), float(L[7]), float(L[8])))
                    counter += 1

            elif line.startswith("HETATM"):
                resname = L[3] + str(L[5])
                atomname = L[2]
                if resname in solvents:
                    solvents[resname][f"{atomname} {str(counter)}"] = (float(L[6]), float(L[7]), float(L[8]))
                    counter += 1
                else:
                    solvents[resname] = {f"{atomname} {str(counter)}": (float(L[6]), float(L[7]), float(L[8]))}
                counter += 1
    
    return resis


def get_pdbs_labels(directory):
    """gets the data dictionary and [pdb string names] 

    inputs: path to directory where input structures are saved"""
    pdbids, data =[],{}
    
    for file in glob.glob(directory + "/PDB/*red.pdb"):
        pdbid = file[-12:-8]
        data[pdbid] = load_pdb(file)
        pdbids.append(pdbid)
    
   

    return data, dd.read_csv(directory + "/pkas.csv", sep=';'), pdbids


def get_targets(df):
    #targets = defaultdict(list)
    targets={}
    for item in df:
        num, resi, chain, pk = item['residue_number'], item['residue_name'], item["chain"], item["pk"]
        targets[resi+str(num)+chain]= pk 

        
    
    return targets

def get_data(pdbs, df, data):
    """returns dictionary of data with pdbids as keys and residueid indexed positions, atomic node and species information, input features (hydrogen indices), and the number of atoms in each sample (residue).
    all_species: {199l: {ASP1A : {CA:1} , ..., {TYR100 : {OXT:1032} } """
    
    all_pos, all_species, all_lengths, all_feats, all_targets, all_ions = {},{},{},{}, {}, {}

    counter=0


    for pdb in pdbs:
        resis = data[pdb] #for one protein
        lengths, species, feats, R ={}, {}, {}, {}
        
        for resid, vals in resis.items():
            hindices = []
            counter=0
            resi_pos, resi_species ={},{}
            
            for atom, pos in vals.items():
                node = atom.split()  # name, pos
                name, nodei =node[0], int(node[1])

                if name[0] == 'H':
                    hindices.append(counter)

                resi_pos[counter] = pos
                resi_species[name] = counter

                counter +=1
            

            f = torch.zeros(counter)        
            f[hindices] = 1
            feats[resid] = f #hydrogen indices

            species[resid] = resi_species 
            R[resid] = resi_pos

            lengths[resid] = counter #num atoms of a sample (resi)

        all_pos[pdb]= R
        all_species[pdb] = species
        all_lengths[pdb] = lengths
        all_feats[pdb] = feats

        #get labels
        d = df[df.iloc[:, 0] == pdb].drop(columns = ["idcode"])
        all_targets[pdb] = get_targets(d.compute().to_dict(orient="records"))

        def ionic_features(pdb, all_ions):

            pdb_ions={}
            Ls = all_lengths[pdb]

            
            for resi in data[pdb].keys():
                resi_species = (all_species[pdb])[resi]
                ion = torch.zeros(Ls[resi])
                resname = resi[:3]
                idxs = [resi_species.get(a) for a in anions[resname]] 
                ion[idxs]= -1
                
                cats = cations[resname]
                if cats:
                    cs = [c for c in cats if c is not None]
                    cats =[resi_species.get(a) for a in cs]
                    cs = [c for c in cats if c is not None]
                    ion[cs] = 1
                pdb_ions[resi] = ion
                
            return pdb_ions
        
        all_ions[pdb] = ionic_features(pdb, {})

    dicts = (all_ions, all_feats, all_pos, all_lengths, {k: v for k, v in all_targets.items() if not k.startswith('N') or k.startswith("CT")})
    titles = ["ions", "Hs", "pos", "L", "targets"]

# Initialize a defaultdict of dicts
    all_data = defaultdict(dict)

# Merge dictionaries with titles
    for title, d in zip(titles, dicts):
        for key, value in d.items():
            all_data[key][title] = value

    return all_data


def boltzmax(x, temp):
    """
    Computes Boltzmann probabilities (Euclidean Softmax) for a tensor of distances.
    
    Parameters:
        distances (torch.Tensor): feature tensor
        temperature (float): The temperature parameter to control the sharpness.
    
    Returns:
        torch.Tensor: A tensor of notprobabilities 
    """
    # Scale the distances by temperature
    scaled_distances = x / temp
    
    # Exponentiate the scaled distances
    x = torch.exp(scaled_distances)
    p = x / torch.max(x) #doing max instead of 
    
    return p


def contrastive_loss(latent_features, species):
    """seperates latent space by enforcing dissimilarity between negative and positive ions"""

    loss = 0.0

    positive_pairs = [(i, j) for i, j in itertools.combinations(range(len(species)), 2) if species[i] == species[j]]
    negative_pairs = [(i, j) for i, j in itertools.combinations(range(3), 2) if species[i] != species[j]]


    # Positive pairs
    for i, j in positive_pairs:
        z_i, z_j = latent_features[i], latent_features[j]
        dist = torch.norm(z_i - z_j, p=2)  
        loss += dist ** 2  

    # Negative pairs
    for i, j in negative_pairs:
        z_i, z_j = latent_features[i], latent_features[j]
        dist = torch.norm(z_i - z_j, p=2) 
        loss += torch.clamp(dist, min=0) ** 2 #min 0 was the margin enforcement



    return loss / (len(positive_pairs) + len(negative_pairs))



def model1(num_nodes, dim, depth, lr, weight_decay):
    net = EGNN_Network(
        num_tokens = 100, #vocabulary siye, "number of unique species"
        num_positions = num_nodes, # unless what you are passing in is an unordered set, set this to the maximum sequence length
        dim = dim,
        depth=depth,
        num_nearest_neighbors = 1, 
    )

    optimizer = torch.optim.Adam(net.parameters(), lr=lr, weight_decay=weight_decay)
    return net, optimizer

def model2():
    pnet = EGNN_Network(
            num_tokens = 50, #vocabulary siye, number of unique species
            num_positions = 23,  #number of nodes         # unless what you are passing in is an unordered set, set this to the maximum sequence length
            dim = 2,# #internal rep size. c has square dependence. richer rep but overfitting for small d.s.
            depth = 3, #number of layers #deeper need more memort to store intermediate reps
            num_nearest_neighbors = 6, #number of nearest neighbors to consider
            dropout=.05,
            m_pool_method='mean')

    return pnet, torch.optim.Adam(pnet.parameters(), lr=.01, weight_decay=.1)


def loop(nepochs, coors, Hs, ion_labels, model, optimizer, negative_slope):
    """run model1"""
    for epoch in range(nepochs):
        optimizer.zero_grad()
        x, _ = model(Hs.unsqueeze(0), coors.unsqueeze(0)) #can turn off return po
        rep = boltzmax((nn.LeakyReLU(negative_slope=negative_slope)(x)), 15)[0] #apply activation (output raw numbers), and softmax (output nonnormalized probabilities)  
        L = contrastive_loss(rep, ion_labels)
        L.backward()
        optimizer.step()

    return rep


import math
import torch
import torch.nn as nn

# Positional Encoding Module
class PositionalEncoding(nn.Module):
    def __init__(self, embed_dim, dropout=0.1, max_len=5000):
        super().__init__()
        self.dropout = nn.Dropout(p=dropout)
        
        pe = torch.zeros(max_len, embed_dim)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, embed_dim, 2, dtype=torch.float) *
                             (-math.log(10000.0) / embed_dim))
        pe[:, 0::2] = torch.sin(position * div_term)
        if embed_dim % 2 == 1:
            # Handle odd dimensions by filling the remaining column with cos()
            pe[:, 1::2] = torch.cos(position * div_term)[:, :pe[:, 1::2].shape[1]]
        else:
            pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(1)  # (max_len, 1, embed_dim)
        self.register_buffer('pe', pe)

    def forward(self, x):
        """
        x: Tensor with shape (seq_length, batch_size, embed_dim)
        """
        x = x + self.pe[:x.size(0)]
        return self.dropout(x)
    
class SimpleMultiheadAttention(nn.Module):
    def __init__(self, embed_dim, num_heads):
        super(SimpleMultiheadAttention, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(embed_dim, num_heads)
    
    def forward(self, x):
        """
        x: Tensor of shape (seq_length, batch_size, embed_dim)
        """
        # In self-attention, query, key, and value are all the same.
        attn_outputs, attn_weights = self.multihead_attn(x, x, x)
        return attn_outputs#, attn_weights

# %%
data, df, pdbs = get_pdbs_labels(directory)

all_data = get_data(pdbs, df, data)

# %%
#run model 1

Ds = {}
for pdb in pdbs:
    print(pdb)
    ds={}

    d = all_data[pdb]
    pos, hs, ions = d["pos"], d["Hs"], d["ions"]#, d["targets"]
    
    
    for sample in pos.keys():
        net, optimizer1 = model1(23, 3, 2, .01, .01) # dim, depth, lr, weight decay #reinit each time lol
        coords = torch.tensor(tuple(pos[sample].values()))
        #L = coords.shape[0]
        x = loop(1, coords, torch.tensor(hs[sample], dtype=int), ions[sample], net, optimizer1, 1) #1 epoch
        y=torch.mean(x, dim=1).unsqueeze(0).detach().numpy()*coords.detach().numpy().T

        ds[sample] = np.gradient(np.gradient(np.column_stack(y).flatten())).reshape(-1,3)
    
    Ds[pdb] = ds #laplacians
# Out:
# 10gs
# /home/jrhoernschemeyer/.local/lib/python3.6/site-packages/ipykernel_launcher.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   app.launch_new_instance()
# 109l
# 111m
# 110m
# 108m
# 110l
# 109m
# 111l
# 108l
# 104m
# 106m
# 105m
# 103m
# 107m
# 107l
# 103l
# 102m
# 102l
# 101m
# 104l

# %%
Ds
# Out:
# {'10gs': {'TYR3A': array([[26.083591 , 16.763145 , -9.101038 ],
#          [-3.796465 , 13.277567 , -8.19049  ],
#          [-4.0812726, 12.006305 , -8.543354 ],
#          [-3.6959634, 11.717552 , -8.627968 ],
#          [-2.7953334, 11.753408 , -9.461644 ],
#          [-2.6996942, 12.538973 , -8.894611 ],
#          [-3.9086761, 11.730747 , -7.366455 ],
#          [-3.604559 , 11.42396  , -7.609083 ],
#          [-3.9966655, 12.398434 , -7.7323694],
#          [-5.1359816, 12.067242 , -7.359657 ],
#          [-4.8576345, 11.498753 , -6.7017026],
#          [-4.168537 , 11.53279  , -7.316995 ],
#          [-4.916022 , 12.164494 , -7.7300496],
#          [-5.079253 , 13.917845 , -6.4738436],
#          [-6.4519734, 10.787449 , -6.816144 ],
#          [-4.746762 , 11.964788 , -5.9805493],
#          [-5.29658  , 12.039425 , -6.763118 ],
#          [-6.2139883, 13.100969 , -6.1470394],
#          [-6.4658546, 12.599992 , -6.361713 ],
#          [-6.801605 , 11.761551 , -5.9059424],
#          [-5.8742266, 16.506311 , 21.35254  ]], dtype=float32),
#   'TYR7A': array([[ 19.935637  ,   8.937985  , -11.113366  ],
#          [  1.3350687 ,   9.8004675 , -11.686467  ],
#          [  1.0812187 ,   9.982953  , -10.005752  ],
#          [  1.304452  ,   8.711317  , -10.612991  ],
#          [  2.0211828 ,   9.331779  , -12.035254  ],
#          [  1.7616532 ,  10.795132  , -11.389199  ],
#          [  0.26565695,  10.172456  , -10.009895  ],
#          [  0.043854  ,   9.755398  ,  -9.831671  ],
#          [  0.37236094,   9.538197  , -10.707425  ],
#          [  0.31600928,   9.941069  ,  -8.945548  ],
#          [  0.62631774,   8.22016   ,  -9.45706   ],
#          [  0.915395  ,   8.245168  ,  -9.936047  ],
#          [  0.8883655 ,   9.739079  ,  -9.586837  ],
#          [  0.20228434,   9.504642  ,  -9.606273  ],
#          [  0.1934712 ,   8.464901  ,  -8.73868   ],
#          [  1.0955496 ,   7.564732  ,  -9.617807  ],
#          [  0.97532535,   9.186551  ,  -9.224176  ],
#          [ -0.03498697,   9.089612  ,  -8.573446  ],
#          [  0.18655396,   7.974779  ,  -8.845549  ],
#          [  0.6344528 ,   8.083023  ,  -8.090875  ],
#          [  0.45371413,  15.233892  ,  14.535175  ]], dtype=float32),
#   'CYS14A': array([[17.243927  ,  9.920928  , -6.99208   ],
#          [-1.1102047 ,  8.998122  , -7.1033163 ],
#          [-2.0527751 ,  8.979572  , -7.148816  ],
#          [-2.2915967 ,  9.111212  , -7.2320156 ],
#          [-2.2406163 , 10.109484  , -7.147467  ],
#          [-3.1111174 ,  9.880108  , -6.8429313 ],
#          [-2.0529313 ,  9.255606  , -8.185659  ],
#          [-1.8371565 ,  9.611914  , -7.593668  ],
#          [  5.4798574, -26.494862 , -32.097225 ]], dtype=float32),
#   'LYS164B': array([[-41.069195 , -25.466053 ,  15.116573 ],
#          [  5.4978237, -18.785097 ,  14.682657 ],
#          [  3.612584 , -19.05017  ,  15.495237 ],
#          [  3.5753093, -19.262552 ,  16.596825 ],
#          [  3.7442548, -20.799074 ,  17.00587  ],
#          [  4.1281815, -22.357687 ,  15.816196 ],
#          [  5.0168643, -19.62878  ,  16.949429 ],
#          [  3.6598368, -21.20097  ,  16.812862 ],
#          [  4.0205193, -20.339668 ,  17.392563 ],
#          [  2.8804908, -20.880638 ,  17.846397 ],
#          [  2.787342 , -21.004135 ,  18.06754  ],
#          [  3.2538295, -20.422932 ,  17.493252 ],
#          [  2.6519017, -20.269825 ,  17.284307 ],
#          [  2.687951 , -19.688469 ,  17.946484 ],
#          [  2.3365989, -20.954876 ,  16.52679  ],
#          [  2.9330926, -18.13115  ,  16.961061 ],
#          [  1.4700499, -18.776459 ,  16.790453 ],
#          [  1.5403004, -18.340088 ,  17.804337 ],
#          [  1.0709252, -19.959291 ,  17.412422 ],
#          [  2.328452 , -18.633934 ,  16.651585 ],
#          [  1.7018695, -17.965145 ,  16.769947 ],
#          [  1.057878 , -35.021656 , -35.9541   ]], dtype=float32)}}

# %%
pdbs = ["109l","111m","110m","108m",
"110l",
"109m",
"111l",
"108l",
"104m",
"106m",
"105m",
"103m",
"107m",
"107l",
"103l",
"102m",
"102l"] + ["104l","101m"]

# %%
A=PositionalEncoding(22)

# %%
pdbs = random.sample(pdbs, len(pdbs))
pdbs
# Out:
# ['104m',
#  '103m',
#  '101m',
#  '104l',
#  '111l',
#  '107l',
#  '109m',
#  '108m',
#  '111m',
#  '108l',
#  '106m',
#  '105m',
#  '102l',
#  '109l',
#  '107m',
#  '110l',
#  '102m',
#  '103l',
#  '10gs',
#  '110m']

# %%
#pdbs = random.sample(pdbs, len(pdbs))
#print(shuffled_list)  # A new shuffled list
mha = SimpleMultiheadAttention(22, 1)
import random
#mha = SimpleMultiheadAttention(22, 1)
A = PositionalEncoding(22)

def model2():

    pnet = EGNN_Network(
            num_tokens = 3, #vocabulary siye, number of unique species
            num_positions = 23,  #number of nodes         # unless what you are passing in is an unordered set, set this to the maximum sequence length
            dim = 2, #internal rep size. c has square dependence. richer rep but overfitting for small d.s.
            depth = 3, #number of layers #deeper need more memort to store intermediate reps
            num_nearest_neighbors = 2, #number of nearest neighbors to conside1
            dropout=0.05,
            m_pool_method='mean')

    return pnet, torch.optim.Adam(pnet.parameters(), lr=.0001, weight_decay=.01)


outs2={}
losses={}
pnet, optimizer3 = model2()
fails={}
optimizer3 = torch.optim.Adam(
    list(pnet.parameters()) + list(mha.parameters()),
    lr=0.0001, weight_decay=.01)
#{}
#def run_m2(pdbs, all_data):
nepochs=50


results, vresults ={},{}
for i in range(nepochs):
    #print(f"starting loop {i}")
    results[i]=[]
    vresults[i] = []
    
    
    for pdb in pdbs[:16]:
        
        #if pdb not in fails:
        ##fails[pdb] = []
        ##outie = {}
        #print(pdb)
        Ddict = Ds[pdb]
    

        d = all_data[pdb]
        pos, T = d["pos"], d["targets"]
        #a=list(T.values())
        #a.sort()
        #print(a)

        
        #l = list(pos.keys())
        samples = random.sample(list(pos.keys()), len(pos))


        for sample in pos.keys():

            coords = torch.tensor(np.gradient(np.gradient(torch.tensor(tuple(pos[sample].values())))))
            D=torch.tensor(Ddict[sample])
            

        

            loss = torch.nn.HuberLoss()

            ins = torch.ones(coords[0].shape[1], dtype=int)
            ins[0]=0.
            ins[-1] = 2.#first index 0, all other atoms have index 1, terminal side chain atom has index 2
            resname=sample[:3]
            label=T.get(resname + sample[3:-1].strip("ABCDEFGHIJKLMNOPQRSTUVWXYZ") + sample[-1])


            if not label:
                label = T.get(resname + str(int(sample [3:-1].strip("ABCDEFGHIJKLMNOPQRSTUVWXYZ")) - 1) + sample[-1])
                
            if not label:
                label = float(np.random.randn(1))

            


            optimizer3.zero_grad()

            y=(pnet(torch.tensor(ins, dtype=int).unsqueeze(0), torch.tensor(D).unsqueeze(0))[0])#, dim=-1)
            
            

            #x=y[0].unsqueeze(1).unsqueeze(2)

            #mha = SimpleMultiheadAttention(1, 1)
            #output = mha(x
            output = mha(A(y[0].unsqueeze(2)))



            
            #pred=torch.max(torch.mean(output, dim=-0))
            pred = 10**torch.log((1+torch.abs(torch.sum(torch.sum(output[0],dim=-2))))) #torch.sum(output[0][0])/3
            #pred = torch.sum(torch.abs((torch.mean(y[0],dim=1))))
            #pred = torch.max(output[0][1::]) 


            #att = torch.stack([o[0][0] for o in output])
            #pred = torch.matmul(torch.tensor(y[0][:,0] * y[0][:,1]),att)
            #pred = torch.sum(att) * torch.mean(att)

            
            loss2=loss(pred, torch.tensor(label))
            

            results[i].append((pdb, sample, round(pred.detach().item(),4), label, round(loss2.item(), 5)))
            


            loss2.backward()

            
            optimizer3.step()


    print("finished one round")


    
    pdbs2 = pdbs[16::]
    
    for pdb in pdbs2:
        d = all_data[pdb]
        pos, T = d["pos"], d["targets"]
        Ddict = Ds[pdb]

        for sample in pos.keys():

            coords = torch.tensor(np.gradient(np.gradient(torch.tensor(tuple(pos[sample].values())))))
            D=torch.tensor(Ddict[sample])
            
            ins = torch.ones(coords[0].shape[1], dtype=int)
            ins[0]=0.
            ins[-1] = 2.#first index 0, all other atoms have index 1, terminal side chain atom has index 2
            resname=sample[:3]
            label=T.get(resname + sample[3:-1].strip("ABCDEFGHIJKLMNOPQRSTUVWXYZ") + sample[-1])

            if not label:
                label = T.get(resname + str(int(sample [3:-1].strip("ABCDEFGHIJKLMNOPQRSTUVWXYZ")) - 1) + sample[-1])

            
            if not label:
                label = float(np.random.randn(1))

            #y=10/(0.1 + 10**(torch.mean(pnet(torch.tensor(ins, dtype=int).unsqueeze(0), torch.tensor(D).unsqueeze(0))[0],dim=-1)))
            y=(pnet(torch.tensor(ins, dtype=int).unsqueeze(0), torch.tensor(D).unsqueeze(0))[0])#,dim=-1))
            x=A(y[0].unsqueeze(2))
        
            #mha = SimpleMultiheadAttention(1, 1)
            #output = mha(x
            output = mha(x)
            
            #output = x[0][-6::]
            #print(label)
            #pred = torch.mean(output[0][1::]) #one token for every pka, which is rep by 6 nodes
            #pred=torch.max(torch.mean(output, dim=0))
            #pred = torch.sum(output[0][0])/3
            pred = 10**torch.log((1+torch.abs(torch.sum(torch.sum(output[0],dim=-2))))) #torch.sum(output[0][0])/3

            #torch.mean(y[0],dim=1) #seems to tell about the resi species in both its mean and sum

            #print(torch.mean(torch.abs((torch.mean(y[0],dim=1)))))
            #pred = torch.sum(torch.abs((torch.mean(y[0],dim=1))))
            #att = torch.stack([o[0][0] for o in output])
            #pred = torch.matmul(torch.tensor(y[0][:,0] * y[0][:,1]),att)
            #pred = torch.sum(att) * torch.mean(att)
            #print("")
            #print("")
            loss2=loss(pred, torch.tensor(label))

            print(sample)
            print(label)
            print(pred)
            print("")
            
            #outie[sample] = y
            vresults[i].append((pdb, sample, round(pred.detach().item(),4), label, round(loss2.item(), 5)))
# Out:
# /home/jrhoernschemeyer/.local/lib/python3.6/site-packages/ipykernel_launcher.py:89: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# finished one round
# GLU5A
# 2.17026
# tensor(5.7259, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.11289
# tensor(4.9829, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.316330000000001
# tensor(7.2010, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4738
# tensor(6.3477, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.5851599999999997
# tensor(7.3604, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.24728
# tensor(1.6267, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.51429
# tensor(13.3064, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.83166
# tensor(3.1400, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8763
# tensor(6.2408, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.323189999999999
# tensor(6.9802, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.28936
# tensor(3.7737, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.22865
# tensor(9.5834, grad_fn=<PowBackward1>)
#
# LYS43A
# 11.9456
# tensor(8.1343, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.8055
# tensor(3.0966, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.2767
# tensor(11.2822, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52289
# tensor(15.9485, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.7983
# tensor(10.1657, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.33478
# tensor(4.8881, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.27515
# tensor(4.9381, grad_fn=<PowBackward1>)
# /home/jrhoernschemeyer/.local/lib/python3.6/site-packages/ipykernel_launcher.py:156: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# LYS57A
# 11.129000000000001
# tensor(8.8799, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.6525199999999995
# tensor(5.2643, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.50623
# tensor(1.7114, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4535
# tensor(6.9973, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.4535
# tensor(7.8816, grad_fn=<PowBackward1>)
#
# LYS78A
# 11.5737
# tensor(9.7237, grad_fn=<PowBackward1>)
#
# LYS79A
# 11.5478
# tensor(12.3563, grad_fn=<PowBackward1>)
#
# LYS80A
# 11.5478
# tensor(6.5586, grad_fn=<PowBackward1>)
#
# HIS82A
# 5.54
# tensor(9.1081, grad_fn=<PowBackward1>)
#
# HIS83A
# 5.54
# tensor(8.1565, grad_fn=<PowBackward1>)
#
# GLU84A
# 2.61539
# tensor(6.4923, grad_fn=<PowBackward1>)
#
# GLU86A
# 2.36996
# tensor(6.7760, grad_fn=<PowBackward1>)
#
# LYS88A
# 10.6318
# tensor(5.5201, grad_fn=<PowBackward1>)
#
# HIS94A
# 5.422999999999999
# tensor(5.7500, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.1679
# tensor(7.4413, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.688680000000001
# tensor(6.6646, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9206
# tensor(8.9898, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.088
# tensor(10.7016, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.603
# tensor(6.6625, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6550599999999998
# tensor(3.8982, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.99917
# tensor(5.4305, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.94645
# tensor(5.6866, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.79091
# tensor(5.9141, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.05922
# tensor(6.5804, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.6458800000000005
# tensor(1.9973, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.4912
# tensor(8.3307, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.7402599999999997
# tensor(1.1134, grad_fn=<PowBackward1>)
#
# LYS141A
# 10.1161
# tensor(7.7032, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.47553900000000004
# tensor(1.3981, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.22
# tensor(13.5643, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0124
# tensor(9.2553, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5581
# tensor(5.7868, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.79943
# tensor(6.0019, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4895
# tensor(6.3550, grad_fn=<PowBackward1>)
#
# GLU5A
# 3.6048699999999996
# tensor(3.3671, grad_fn=<PowBackward1>)
#
# ASP10A
# 1.3983299999999999
# tensor(1.6384, grad_fn=<PowBackward1>)
#
# GLU11A
# 4.21061
# tensor(5.3859, grad_fn=<PowBackward1>)
#
# LYS16A
# 10.2553
# tensor(4.9884, grad_fn=<PowBackward1>)
#
# TYR18A
# 11.1976
# tensor(11.1792, grad_fn=<PowBackward1>)
#
# LYS19A
# 11.0319
# tensor(7.8410, grad_fn=<PowBackward1>)
#
# ASP20A
# 2.89969
# tensor(2.5215, grad_fn=<PowBackward1>)
#
# GLU22A
# 3.00215
# tensor(12.1070, grad_fn=<PowBackward1>)
#
# TYR24A
# 10.3155
# tensor(8.3262, grad_fn=<PowBackward1>)
#
# TYR25A
# 8.89904
# tensor(8.1724, grad_fn=<PowBackward1>)
#
# HIS31A
# 7.8168
# tensor(7.3004, grad_fn=<PowBackward1>)
#
# LYS35A
# -2.538888435263879
# tensor(8.5291, grad_fn=<PowBackward1>)
#
# ASP43CA
# 0.6230837925079995
# tensor(1.4642, grad_fn=<PowBackward1>)
#
# LYS46A
# 0.4765795535958349
# tensor(9.5202, grad_fn=<PowBackward1>)
#
# GLU48A
# -0.18755313271883878
# tensor(5.2417, grad_fn=<PowBackward1>)
#
# ASP50A
# -0.20006039844110657
# tensor(1.8473, grad_fn=<PowBackward1>)
#
# LYS51A
# 0.9920057351793174
# tensor(9.8204, grad_fn=<PowBackward1>)
#
# LYS63A
# 1.6688972131804538
# tensor(9.4194, grad_fn=<PowBackward1>)
#
# ASP64A
# -1.2409850107874019
# tensor(3.1599, grad_fn=<PowBackward1>)
#
# GLU65A
# 4.07334
# tensor(6.8764, grad_fn=<PowBackward1>)
#
# GLU67A
# -0.34035981614362276
# tensor(4.6548, grad_fn=<PowBackward1>)
#
# LYS68A
# 1.6278739998383767
# tensor(7.1660, grad_fn=<PowBackward1>)
#
# ASP73A
# 3.1071299999999997
# tensor(2.6357, grad_fn=<PowBackward1>)
#
# ASP75A
# -0.016745289580858816
# tensor(3.0307, grad_fn=<PowBackward1>)
#
# LYS86A
# 11.1797
# tensor(8.1155, grad_fn=<PowBackward1>)
#
# LYS88A
# 0.2031272757479797
# tensor(7.9692, grad_fn=<PowBackward1>)
#
# TYR91A
# 0.6406558755855986
# tensor(10.0275, grad_fn=<PowBackward1>)
#
# ASP92A
# 1.05585
# tensor(1.6354, grad_fn=<PowBackward1>)
#
# ASP95A
# -1.4013184507090075
# tensor(1.0138, grad_fn=<PowBackward1>)
#
# GLU111A
# -0.39977701346054834
# tensor(5.9257, grad_fn=<PowBackward1>)
#
# LYS127A
# -1.1281690551721109
# tensor(8.6440, grad_fn=<PowBackward1>)
#
# ASP130A
# 0.32675196481071594
# tensor(3.0565, grad_fn=<PowBackward1>)
#
# GLU131A
# -1.56048336156761
# tensor(6.0831, grad_fn=<PowBackward1>)
#
# LYS138A
# 1.6816414631335674
# tensor(7.7694, grad_fn=<PowBackward1>)
#
# TYR142A
# 2.0020835595956803
# tensor(13.6070, grad_fn=<PowBackward1>)
#
# LYS150A
# -0.8215331481002759
# tensor(12.2361, grad_fn=<PowBackward1>)
#
# ASP162A
# -0.7051600035877021
# tensor(2.8699, grad_fn=<PowBackward1>)
#
# TYR164A
# -0.04162987161120115
# tensor(5.4174, grad_fn=<PowBackward1>)
#
# LYS165A
# -0.22235344449093092
# tensor(7.0568, grad_fn=<PowBackward1>)
#
# TYR3A
# 11.3108
# tensor(8.9616, grad_fn=<PowBackward1>)
#
# TYR7A
# 9.66513
# tensor(8.8931, grad_fn=<PowBackward1>)
#
# CYS14A
# 12.3283
# tensor(1.8112, grad_fn=<PowBackward1>)
#
# ASP23A
# 1.6541299999999999
# tensor(4.6240, grad_fn=<PowBackward1>)
#
# LYS29A
# 11.1225
# tensor(5.8831, grad_fn=<PowBackward1>)
#
# GLU30A
# 1.8763900000000002
# tensor(2.1043, grad_fn=<PowBackward1>)
#
# GLU31A
# 3.491
# tensor(5.1333, grad_fn=<PowBackward1>)
#
# GLU36A
# 4.053640000000001
# tensor(3.5663, grad_fn=<PowBackward1>)
#
# GLU40A
# 3.83331
# tensor(3.5692, grad_fn=<PowBackward1>)
#
# LYS44A
# 10.5261
# tensor(8.4784, grad_fn=<PowBackward1>)
#
# CYS47A
# 10.7954
# tensor(1.9327, grad_fn=<PowBackward1>)
#
# TYR49A
# 13.3563
# tensor(8.7001, grad_fn=<PowBackward1>)
#
# LYS54A
# 11.4235
# tensor(8.1003, grad_fn=<PowBackward1>)
#
# ASP57A
# 3.12194
# tensor(2.6640, grad_fn=<PowBackward1>)
#
# ASP59A
# 3.76229
# tensor(1.5549, grad_fn=<PowBackward1>)
#
# TYR63A
# 9.93648
# tensor(9.3756, grad_fn=<PowBackward1>)
#
# HIS71A
# 5.37399
# tensor(9.1095, grad_fn=<PowBackward1>)
#
# TYR79A
# 14.0334
# tensor(11.2881, grad_fn=<PowBackward1>)
#
# LYS81A
# 11.7278
# tensor(11.2745, grad_fn=<PowBackward1>)
#
# ASP82A
# 2.10677
# tensor(1.6065, grad_fn=<PowBackward1>)
#
# GLU85A
# 2.99493
# tensor(5.4880, grad_fn=<PowBackward1>)
#
# ASP90A
# -2.08976
# tensor(2.8799, grad_fn=<PowBackward1>)
#
# ASP94A
# 2.04279
# tensor(2.8761, grad_fn=<PowBackward1>)
#
# GLU97A
# 0.720119
# tensor(8.0165, grad_fn=<PowBackward1>)
#
# ASP98A
# 3.7668800000000005
# tensor(5.7309, grad_fn=<PowBackward1>)
#
# CYS101A
# 10.5065
# tensor(1.1240, grad_fn=<PowBackward1>)
#
# LYS102A
# 11.2875
# tensor(7.7186, grad_fn=<PowBackward1>)
#
# TYR103A
# 14.4342
# tensor(14.4951, grad_fn=<PowBackward1>)
#
# TYR108A
# 10.0359
# tensor(5.5014, grad_fn=<PowBackward1>)
#
# TYR111A
# 10.8418
# tensor(7.3674, grad_fn=<PowBackward1>)
#
# GLU112A
# 1.77688
# tensor(5.0811, grad_fn=<PowBackward1>)
#
# LYS115A
# 12.3084
# tensor(8.8483, grad_fn=<PowBackward1>)
#
# ASP116A
# 3.5621
# tensor(3.2987, grad_fn=<PowBackward1>)
#
# ASP117A
# 3.24708
# tensor(3.5798, grad_fn=<PowBackward1>)
#
# TYR118A
# 11.1035
# tensor(6.4230, grad_fn=<PowBackward1>)
#
# LYS120A
# 11.0595
# tensor(9.2607, grad_fn=<PowBackward1>)
#
# LYS127A
# 10.463
# tensor(9.9454, grad_fn=<PowBackward1>)
#
# GLU130A
# 2.8519799999999997
# tensor(4.1664, grad_fn=<PowBackward1>)
#
# LYS140A
# 10.3472
# tensor(6.8101, grad_fn=<PowBackward1>)
#
# ASP146A
# 3.68194
# tensor(2.4293, grad_fn=<PowBackward1>)
#
# ASP152A
# 2.24571
# tensor(1.9600, grad_fn=<PowBackward1>)
#
# TYR153A
# 13.6518
# tensor(10.8947, grad_fn=<PowBackward1>)
#
# ASP157A
# 2.7138299999999997
# tensor(6.6467, grad_fn=<PowBackward1>)
#
# HIS162A
# 5.78009
# tensor(9.5699, grad_fn=<PowBackward1>)
#
# GLU163A
# 4.02044
# tensor(5.6325, grad_fn=<PowBackward1>)
#
# CYS169A
# 12.177999999999999
# tensor(1.7770, grad_fn=<PowBackward1>)
#
# ASP171A
# 4.0267800000000005
# tensor(1.0720, grad_fn=<PowBackward1>)
#
# TYR179A
# 16.7491
# tensor(6.5051, grad_fn=<PowBackward1>)
#
# LYS188A
# 10.5335
# tensor(8.5013, grad_fn=<PowBackward1>)
#
# LYS190A
# 10.5017
# tensor(5.2330, grad_fn=<PowBackward1>)
#
# GLU197A
# 4.41164
# tensor(6.1627, grad_fn=<PowBackward1>)
#
# TYR198A
# 11.2606
# tensor(10.7779, grad_fn=<PowBackward1>)
#
# LYS208A
# 11.1899
# tensor(9.8792, grad_fn=<PowBackward1>)
#
# TYR3B
# 11.3018
# tensor(6.8310, grad_fn=<PowBackward1>)
#
# TYR7B
# 9.698139999999999
# tensor(8.1027, grad_fn=<PowBackward1>)
#
# CYS14B
# 12.367
# tensor(1.9192, grad_fn=<PowBackward1>)
#
# ASP23B
# 1.54906
# tensor(3.5788, grad_fn=<PowBackward1>)
#
# LYS29B
# 11.1642
# tensor(7.8406, grad_fn=<PowBackward1>)
#
# GLU30B
# 1.9062700000000001
# tensor(3.4901, grad_fn=<PowBackward1>)
#
# GLU31B
# 3.4797599999999997
# tensor(4.4753, grad_fn=<PowBackward1>)
#
# GLU36B
# 4.033440000000001
# tensor(4.1379, grad_fn=<PowBackward1>)
#
# GLU40B
# 3.8428
# tensor(6.4129, grad_fn=<PowBackward1>)
#
# LYS44B
# 10.3911
# tensor(9.3033, grad_fn=<PowBackward1>)
#
# CYS47B
# 10.8956
# tensor(1.1074, grad_fn=<PowBackward1>)
#
# TYR49B
# 13.3665
# tensor(13.7176, grad_fn=<PowBackward1>)
#
# LYS54B
# 11.4268
# tensor(9.7768, grad_fn=<PowBackward1>)
#
# ASP57B
# 3.14929
# tensor(4.1077, grad_fn=<PowBackward1>)
#
# ASP59B
# 3.75998
# tensor(2.6981, grad_fn=<PowBackward1>)
#
# TYR63B
# 10.0447
# tensor(7.7792, grad_fn=<PowBackward1>)
#
# HIS71B
# 5.376519999999999
# tensor(6.2963, grad_fn=<PowBackward1>)
#
# TYR79B
# 14.1107
# tensor(8.7607, grad_fn=<PowBackward1>)
#
# LYS81B
# 11.6971
# tensor(8.4951, grad_fn=<PowBackward1>)
#
# ASP82B
# 2.10338
# tensor(2.8257, grad_fn=<PowBackward1>)
#
# GLU85B
# 3.0055
# tensor(6.4842, grad_fn=<PowBackward1>)
#
# ASP90B
# -1.4355200000000001
# tensor(3.4410, grad_fn=<PowBackward1>)
#
# ASP94B
# 2.08924
# tensor(3.4717, grad_fn=<PowBackward1>)
#
# GLU97B
# 0.709659
# tensor(8.6621, grad_fn=<PowBackward1>)
#
# ASP98B
# 3.46987
# tensor(1.7839, grad_fn=<PowBackward1>)
#
# CYS101B
# 10.4488
# tensor(2.1371, grad_fn=<PowBackward1>)
#
# LYS102B
# 11.1985
# tensor(9.4680, grad_fn=<PowBackward1>)
#
# TYR103B
# 14.3269
# tensor(6.4676, grad_fn=<PowBackward1>)
#
# TYR108B
# 9.863719999999999
# tensor(8.9121, grad_fn=<PowBackward1>)
#
# TYR111B
# 10.9655
# tensor(6.9305, grad_fn=<PowBackward1>)
#
# GLU112B
# 1.7390599999999998
# tensor(4.3915, grad_fn=<PowBackward1>)
#
# LYS115B
# 12.3262
# tensor(9.0939, grad_fn=<PowBackward1>)
#
# ASP116B
# 3.56744
# tensor(1.0279, grad_fn=<PowBackward1>)
#
# ASP117B
# 3.2548
# tensor(1.6243, grad_fn=<PowBackward1>)
#
# TYR118B
# 11.110999999999999
# tensor(5.2706, grad_fn=<PowBackward1>)
#
# LYS120B
# 11.046
# tensor(8.9544, grad_fn=<PowBackward1>)
#
# LYS127B
# 10.4812
# tensor(6.6983, grad_fn=<PowBackward1>)
#
# GLU130B
# 2.83366
# tensor(6.9697, grad_fn=<PowBackward1>)
#
# LYS140B
# 10.3419
# tensor(6.0400, grad_fn=<PowBackward1>)
#
# ASP146B
# 3.70626
# tensor(2.1059, grad_fn=<PowBackward1>)
#
# ASP152B
# 2.26307
# tensor(1.2500, grad_fn=<PowBackward1>)
#
# TYR153B
# 13.8237
# tensor(6.1184, grad_fn=<PowBackward1>)
#
# ASP157B
# 2.70568
# tensor(2.5646, grad_fn=<PowBackward1>)
#
# HIS162B
# 5.72175
# tensor(6.5938, grad_fn=<PowBackward1>)
#
# GLU163B
# 4.07659
# tensor(5.0964, grad_fn=<PowBackward1>)
#
# CYS169B
# 12.1804
# tensor(1.0944, grad_fn=<PowBackward1>)
#
# ASP171B
# 4.01126
# tensor(2.5814, grad_fn=<PowBackward1>)
#
# TYR179B
# 16.6717
# tensor(7.0756, grad_fn=<PowBackward1>)
#
# LYS188B
# 10.5252
# tensor(6.8715, grad_fn=<PowBackward1>)
#
# LYS190B
# 10.4915
# tensor(5.0009, grad_fn=<PowBackward1>)
#
# GLU197B
# 4.41136
# tensor(4.9958, grad_fn=<PowBackward1>)
#
# TYR198B
# 11.1961
# tensor(9.3980, grad_fn=<PowBackward1>)
#
# LYS208B
# 11.1694
# tensor(8.1409, grad_fn=<PowBackward1>)
#
# GLU5A
# 2.25882
# tensor(7.0128, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.30527
# tensor(3.3295, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.34365
# tensor(5.4857, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4696
# tensor(5.1100, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.54005
# tensor(5.5234, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.56832
# tensor(2.9466, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.58891
# tensor(5.7940, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.88935
# tensor(3.0171, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8792
# tensor(6.3292, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.46405
# tensor(6.7107, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.2631200000000002
# tensor(3.7836, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.32242
# tensor(3.4803, grad_fn=<PowBackward1>)
#
# LYS43A
# 12.0184
# tensor(11.1731, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.70955
# tensor(1.7178, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.1675
# tensor(11.3794, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52923
# tensor(7.8794, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.8337
# tensor(8.5149, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.71395
# tensor(3.8893, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.3791
# tensor(6.0577, grad_fn=<PowBackward1>)
#
# LYS57A
# 11.2713
# tensor(9.6460, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.25727
# tensor(8.0912, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.16063
# tensor(1.6299, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4527
# tensor(8.1500, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.4527
# tensor(10.1850, grad_fn=<PowBackward1>)
#
# HIS65A
# 5.11776
# tensor(5.6025, grad_fn=<PowBackward1>)
#
# LYS78A
# 11.748
# tensor(8.3974, grad_fn=<PowBackward1>)
#
# LYS79A
# 11.4699
# tensor(8.2303, grad_fn=<PowBackward1>)
#
# LYS80A
# 11.4699
# tensor(6.7922, grad_fn=<PowBackward1>)
#
# HIS82A
# 5.30687
# tensor(9.4828, grad_fn=<PowBackward1>)
#
# HIS83A
# 5.30687
# tensor(5.9325, grad_fn=<PowBackward1>)
#
# GLU84A
# 2.66977
# tensor(7.4310, grad_fn=<PowBackward1>)
#
# GLU86A
# 2.17203
# tensor(3.1117, grad_fn=<PowBackward1>)
#
# LYS88A
# 10.6615
# tensor(7.1786, grad_fn=<PowBackward1>)
#
# HIS94A
# 5.22698
# tensor(7.4942, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.3312
# tensor(6.4433, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.59868
# tensor(6.6061, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9383
# tensor(6.0241, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.1126
# tensor(6.4968, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.5428
# tensor(6.8760, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6996599999999997
# tensor(5.1751, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.5291799999999998
# tensor(5.7858, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.9911
# tensor(5.7906, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.74408
# tensor(10.2696, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.10426
# tensor(6.2626, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.63867
# tensor(1.1523, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.3455
# tensor(9.8284, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.6754300000000004
# tensor(4.2284, grad_fn=<PowBackward1>)
#
# LYS141A
# 9.825389999999999
# tensor(8.8716, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.7921199999999999
# tensor(1.9369, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.148
# tensor(10.3766, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0179
# tensor(9.8608, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5509
# tensor(4.8612, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.8077699999999997
# tensor(4.5869, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4038
# tensor(6.2748, grad_fn=<PowBackward1>)
#
# finished one round
# GLU5A
# 2.17026
# tensor(5.1782, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.11289
# tensor(5.8279, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.316330000000001
# tensor(8.7971, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4738
# tensor(10.4957, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.5851599999999997
# tensor(3.5421, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.24728
# tensor(2.5074, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.51429
# tensor(7.8810, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.83166
# tensor(2.2810, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8763
# tensor(9.6913, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.323189999999999
# tensor(7.2247, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.28936
# tensor(9.5444, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.22865
# tensor(4.6337, grad_fn=<PowBackward1>)
#
# LYS43A
# 11.9456
# tensor(9.1152, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.8055
# tensor(3.5162, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.2767
# tensor(14.0683, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52289
# tensor(4.6057, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.7983
# tensor(12.8971, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.33478
# tensor(5.1015, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.27515
# tensor(2.6806, grad_fn=<PowBackward1>)
#
# LYS57A
# 11.129000000000001
# tensor(9.1066, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.6525199999999995
# tensor(5.0891, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.50623
# tensor(3.3111, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4535
# tensor(10.7854, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.4535
# tensor(9.8723, grad_fn=<PowBackward1>)
#
# LYS78A
# 11.5737
# tensor(14.8272, grad_fn=<PowBackward1>)
#
# LYS79A
# 11.5478
# tensor(9.3978, grad_fn=<PowBackward1>)
#
# LYS80A
# 11.5478
# tensor(9.7412, grad_fn=<PowBackward1>)
#
# HIS82A
# 5.54
# tensor(7.7801, grad_fn=<PowBackward1>)
#
# HIS83A
# 5.54
# tensor(7.4292, grad_fn=<PowBackward1>)
#
# GLU84A
# 2.61539
# tensor(6.5528, grad_fn=<PowBackward1>)
#
# GLU86A
# 2.36996
# tensor(6.4569, grad_fn=<PowBackward1>)
#
# LYS88A
# 10.6318
# tensor(8.4687, grad_fn=<PowBackward1>)
#
# HIS94A
# 5.422999999999999
# tensor(8.1297, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.1679
# tensor(7.5037, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.688680000000001
# tensor(10.9813, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9206
# tensor(10.6595, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.088
# tensor(14.1066, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.603
# tensor(9.0227, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6550599999999998
# tensor(5.9668, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.99917
# tensor(5.8248, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.94645
# tensor(7.0499, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.79091
# tensor(6.2921, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.05922
# tensor(5.8845, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.6458800000000005
# tensor(2.7751, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.4912
# tensor(10.6944, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.7402599999999997
# tensor(6.0527, grad_fn=<PowBackward1>)
#
# LYS141A
# 10.1161
# tensor(10.8818, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.47553900000000004
# tensor(4.3701, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.22
# tensor(8.9885, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0124
# tensor(6.2869, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5581
# tensor(10.2709, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.79943
# tensor(3.1360, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4895
# tensor(9.4804, grad_fn=<PowBackward1>)
#
# GLU5A
# 3.6048699999999996
# tensor(5.1757, grad_fn=<PowBackward1>)
#
# ASP10A
# 1.3983299999999999
# tensor(1.6651, grad_fn=<PowBackward1>)
#
# GLU11A
# 4.21061
# tensor(3.2236, grad_fn=<PowBackward1>)
#
# LYS16A
# 10.2553
# tensor(8.9217, grad_fn=<PowBackward1>)
#
# TYR18A
# 11.1976
# tensor(10.5982, grad_fn=<PowBackward1>)
#
# LYS19A
# 11.0319
# tensor(12.5097, grad_fn=<PowBackward1>)
#
# ASP20A
# 2.89969
# tensor(1.9101, grad_fn=<PowBackward1>)
#
# GLU22A
# 3.00215
# tensor(6.5131, grad_fn=<PowBackward1>)
#
# TYR24A
# 10.3155
# tensor(9.5392, grad_fn=<PowBackward1>)
#
# TYR25A
# 8.89904
# tensor(10.0579, grad_fn=<PowBackward1>)
#
# HIS31A
# 7.8168
# tensor(6.4050, grad_fn=<PowBackward1>)
#
# LYS35A
# 0.11492162220636401
# tensor(9.1830, grad_fn=<PowBackward1>)
#
# ASP43CA
# -2.14909803636363
# tensor(2.2623, grad_fn=<PowBackward1>)
#
# LYS46A
# -0.007407879225254849
# tensor(9.3869, grad_fn=<PowBackward1>)
#
# GLU48A
# 0.8689898489102715
# tensor(3.4401, grad_fn=<PowBackward1>)
#
# ASP50A
# 1.0194043705254054
# tensor(2.6897, grad_fn=<PowBackward1>)
#
# LYS51A
# -1.2106787564671158
# tensor(11.0008, grad_fn=<PowBackward1>)
#
# LYS63A
# 1.129869995050319
# tensor(9.6696, grad_fn=<PowBackward1>)
#
# ASP64A
# -0.7444261497800501
# tensor(3.9320, grad_fn=<PowBackward1>)
#
# GLU65A
# 4.07334
# tensor(6.3970, grad_fn=<PowBackward1>)
#
# GLU67A
# 1.3266331591907923
# tensor(4.0915, grad_fn=<PowBackward1>)
#
# LYS68A
# -0.35148513527856656
# tensor(10.5845, grad_fn=<PowBackward1>)
#
# ASP73A
# 3.1071299999999997
# tensor(2.6031, grad_fn=<PowBackward1>)
#
# ASP75A
# 1.0349655465858754
# tensor(2.0974, grad_fn=<PowBackward1>)
#
# LYS86A
# 11.1797
# tensor(13.6333, grad_fn=<PowBackward1>)
#
# LYS88A
# -0.6820984557299155
# tensor(9.1859, grad_fn=<PowBackward1>)
#
# TYR91A
# -0.13415265060832743
# tensor(12.5224, grad_fn=<PowBackward1>)
#
# ASP92A
# 1.05585
# tensor(2.7543, grad_fn=<PowBackward1>)
#
# ASP95A
# -1.6232053130343804
# tensor(2.5946, grad_fn=<PowBackward1>)
#
# GLU111A
# 0.9045330538507481
# tensor(6.0263, grad_fn=<PowBackward1>)
#
# LYS127A
# -0.2675915016534316
# tensor(9.3005, grad_fn=<PowBackward1>)
#
# ASP130A
# 1.0873214645749918
# tensor(2.0666, grad_fn=<PowBackward1>)
#
# GLU131A
# 1.5227358627770742
# tensor(9.7941, grad_fn=<PowBackward1>)
#
# LYS138A
# -2.214289931278165
# tensor(12.4752, grad_fn=<PowBackward1>)
#
# TYR142A
# 1.8763834925086706
# tensor(11.6728, grad_fn=<PowBackward1>)
#
# LYS150A
# 1.4491967081406323
# tensor(9.5376, grad_fn=<PowBackward1>)
#
# ASP162A
# -0.1374726041387317
# tensor(1.1014, grad_fn=<PowBackward1>)
#
# TYR164A
# -0.026727385777023733
# tensor(9.9769, grad_fn=<PowBackward1>)
#
# LYS165A
# -1.1757527851615424
# tensor(11.1451, grad_fn=<PowBackward1>)
#
# TYR3A
# 11.3108
# tensor(9.5057, grad_fn=<PowBackward1>)
#
# TYR7A
# 9.66513
# tensor(10.8928, grad_fn=<PowBackward1>)
#
# CYS14A
# 12.3283
# tensor(1.0725, grad_fn=<PowBackward1>)
#
# ASP23A
# 1.6541299999999999
# tensor(2.7900, grad_fn=<PowBackward1>)
#
# LYS29A
# 11.1225
# tensor(13.8573, grad_fn=<PowBackward1>)
#
# GLU30A
# 1.8763900000000002
# tensor(10.6322, grad_fn=<PowBackward1>)
#
# GLU31A
# 3.491
# tensor(4.0772, grad_fn=<PowBackward1>)
#
# GLU36A
# 4.053640000000001
# tensor(7.9004, grad_fn=<PowBackward1>)
#
# GLU40A
# 3.83331
# tensor(7.7606, grad_fn=<PowBackward1>)
#
# LYS44A
# 10.5261
# tensor(7.5620, grad_fn=<PowBackward1>)
#
# CYS47A
# 10.7954
# tensor(1.2872, grad_fn=<PowBackward1>)
#
# TYR49A
# 13.3563
# tensor(10.0793, grad_fn=<PowBackward1>)
#
# LYS54A
# 11.4235
# tensor(9.6144, grad_fn=<PowBackward1>)
#
# ASP57A
# 3.12194
# tensor(5.8943, grad_fn=<PowBackward1>)
#
# ASP59A
# 3.76229
# tensor(2.3936, grad_fn=<PowBackward1>)
#
# TYR63A
# 9.93648
# tensor(11.5580, grad_fn=<PowBackward1>)
#
# HIS71A
# 5.37399
# tensor(6.2717, grad_fn=<PowBackward1>)
#
# TYR79A
# 14.0334
# tensor(9.7301, grad_fn=<PowBackward1>)
#
# LYS81A
# 11.7278
# tensor(10.2511, grad_fn=<PowBackward1>)
#
# ASP82A
# 2.10677
# tensor(2.4952, grad_fn=<PowBackward1>)
#
# GLU85A
# 2.99493
# tensor(4.5065, grad_fn=<PowBackward1>)
#
# ASP90A
# -2.08976
# tensor(3.9568, grad_fn=<PowBackward1>)
#
# ASP94A
# 2.04279
# tensor(1.5136, grad_fn=<PowBackward1>)
#
# GLU97A
# 0.720119
# tensor(4.3092, grad_fn=<PowBackward1>)
#
# ASP98A
# 3.7668800000000005
# tensor(1.0028, grad_fn=<PowBackward1>)
#
# CYS101A
# 10.5065
# tensor(2.0434, grad_fn=<PowBackward1>)
#
# LYS102A
# 11.2875
# tensor(8.8020, grad_fn=<PowBackward1>)
#
# TYR103A
# 14.4342
# tensor(6.9132, grad_fn=<PowBackward1>)
#
# TYR108A
# 10.0359
# tensor(12.1260, grad_fn=<PowBackward1>)
#
# TYR111A
# 10.8418
# tensor(8.7451, grad_fn=<PowBackward1>)
#
# GLU112A
# 1.77688
# tensor(4.0166, grad_fn=<PowBackward1>)
#
# LYS115A
# 12.3084
# tensor(8.9071, grad_fn=<PowBackward1>)
#
# ASP116A
# 3.5621
# tensor(1.6916, grad_fn=<PowBackward1>)
#
# ASP117A
# 3.24708
# tensor(1.7641, grad_fn=<PowBackward1>)
#
# TYR118A
# 11.1035
# tensor(9.4459, grad_fn=<PowBackward1>)
#
# LYS120A
# 11.0595
# tensor(12.3709, grad_fn=<PowBackward1>)
#
# LYS127A
# 10.463
# tensor(10.8815, grad_fn=<PowBackward1>)
#
# GLU130A
# 2.8519799999999997
# tensor(2.2168, grad_fn=<PowBackward1>)
#
# LYS140A
# 10.3472
# tensor(11.8065, grad_fn=<PowBackward1>)
#
# ASP146A
# 3.68194
# tensor(2.4898, grad_fn=<PowBackward1>)
#
# ASP152A
# 2.24571
# tensor(1.2155, grad_fn=<PowBackward1>)
#
# TYR153A
# 13.6518
# tensor(14.0033, grad_fn=<PowBackward1>)
#
# ASP157A
# 2.7138299999999997
# tensor(1.7681, grad_fn=<PowBackward1>)
#
# HIS162A
# 5.78009
# tensor(6.5368, grad_fn=<PowBackward1>)
#
# GLU163A
# 4.02044
# tensor(2.6563, grad_fn=<PowBackward1>)
#
# CYS169A
# 12.177999999999999
# tensor(1.0880, grad_fn=<PowBackward1>)
#
# ASP171A
# 4.0267800000000005
# tensor(4.2682, grad_fn=<PowBackward1>)
#
# TYR179A
# 16.7491
# tensor(9.5524, grad_fn=<PowBackward1>)
#
# LYS188A
# 10.5335
# tensor(13.2977, grad_fn=<PowBackward1>)
#
# LYS190A
# 10.5017
# tensor(12.9979, grad_fn=<PowBackward1>)
#
# GLU197A
# 4.41164
# tensor(3.7018, grad_fn=<PowBackward1>)
#
# TYR198A
# 11.2606
# tensor(11.9138, grad_fn=<PowBackward1>)
#
# LYS208A
# 11.1899
# tensor(10.8212, grad_fn=<PowBackward1>)
#
# TYR3B
# 11.3018
# tensor(10.1526, grad_fn=<PowBackward1>)
#
# TYR7B
# 9.698139999999999
# tensor(7.7652, grad_fn=<PowBackward1>)
#
# CYS14B
# 12.367
# tensor(1.0492, grad_fn=<PowBackward1>)
#
# ASP23B
# 1.54906
# tensor(2.4094, grad_fn=<PowBackward1>)
#
# LYS29B
# 11.1642
# tensor(9.9631, grad_fn=<PowBackward1>)
#
# GLU30B
# 1.9062700000000001
# tensor(3.9931, grad_fn=<PowBackward1>)
#
# GLU31B
# 3.4797599999999997
# tensor(5.0550, grad_fn=<PowBackward1>)
#
# GLU36B
# 4.033440000000001
# tensor(6.1613, grad_fn=<PowBackward1>)
#
# GLU40B
# 3.8428
# tensor(3.9995, grad_fn=<PowBackward1>)
#
# LYS44B
# 10.3911
# tensor(14.4767, grad_fn=<PowBackward1>)
#
# CYS47B
# 10.8956
# tensor(1.7327, grad_fn=<PowBackward1>)
#
# TYR49B
# 13.3665
# tensor(7.6259, grad_fn=<PowBackward1>)
#
# LYS54B
# 11.4268
# tensor(8.8869, grad_fn=<PowBackward1>)
#
# ASP57B
# 3.14929
# tensor(1.9042, grad_fn=<PowBackward1>)
#
# ASP59B
# 3.75998
# tensor(1.2394, grad_fn=<PowBackward1>)
#
# TYR63B
# 10.0447
# tensor(8.4839, grad_fn=<PowBackward1>)
#
# HIS71B
# 5.376519999999999
# tensor(6.5711, grad_fn=<PowBackward1>)
#
# TYR79B
# 14.1107
# tensor(10.3606, grad_fn=<PowBackward1>)
#
# LYS81B
# 11.6971
# tensor(6.4103, grad_fn=<PowBackward1>)
#
# ASP82B
# 2.10338
# tensor(2.0311, grad_fn=<PowBackward1>)
#
# GLU85B
# 3.0055
# tensor(7.3450, grad_fn=<PowBackward1>)
#
# ASP90B
# -1.4355200000000001
# tensor(2.3212, grad_fn=<PowBackward1>)
#
# ASP94B
# 2.08924
# tensor(3.2408, grad_fn=<PowBackward1>)
#
# GLU97B
# 0.709659
# tensor(4.9262, grad_fn=<PowBackward1>)
#
# ASP98B
# 3.46987
# tensor(2.0488, grad_fn=<PowBackward1>)
#
# CYS101B
# 10.4488
# tensor(1.2975, grad_fn=<PowBackward1>)
#
# LYS102B
# 11.1985
# tensor(11.7665, grad_fn=<PowBackward1>)
#
# TYR103B
# 14.3269
# tensor(12.7544, grad_fn=<PowBackward1>)
#
# TYR108B
# 9.863719999999999
# tensor(13.4063, grad_fn=<PowBackward1>)
#
# TYR111B
# 10.9655
# tensor(9.9378, grad_fn=<PowBackward1>)
#
# GLU112B
# 1.7390599999999998
# tensor(5.2982, grad_fn=<PowBackward1>)
#
# LYS115B
# 12.3262
# tensor(10.0837, grad_fn=<PowBackward1>)
#
# ASP116B
# 3.56744
# tensor(1.4383, grad_fn=<PowBackward1>)
#
# ASP117B
# 3.2548
# tensor(3.2333, grad_fn=<PowBackward1>)
#
# TYR118B
# 11.110999999999999
# tensor(11.1356, grad_fn=<PowBackward1>)
#
# LYS120B
# 11.046
# tensor(11.1194, grad_fn=<PowBackward1>)
#
# LYS127B
# 10.4812
# tensor(12.0858, grad_fn=<PowBackward1>)
#
# GLU130B
# 2.83366
# tensor(5.4931, grad_fn=<PowBackward1>)
#
# LYS140B
# 10.3419
# tensor(13.0955, grad_fn=<PowBackward1>)
#
# ASP146B
# 3.70626
# tensor(1.3288, grad_fn=<PowBackward1>)
#
# ASP152B
# 2.26307
# tensor(1.6705, grad_fn=<PowBackward1>)
#
# TYR153B
# 13.8237
# tensor(9.9494, grad_fn=<PowBackward1>)
#
# ASP157B
# 2.70568
# tensor(1.1800, grad_fn=<PowBackward1>)
#
# HIS162B
# 5.72175
# tensor(13.6004, grad_fn=<PowBackward1>)
#
# GLU163B
# 4.07659
# tensor(7.6312, grad_fn=<PowBackward1>)
#
# CYS169B
# 12.1804
# tensor(2.8166, grad_fn=<PowBackward1>)
#
# ASP171B
# 4.01126
# tensor(3.2038, grad_fn=<PowBackward1>)
#
# TYR179B
# 16.6717
# tensor(10.2344, grad_fn=<PowBackward1>)
#
# LYS188B
# 10.5252
# tensor(9.6697, grad_fn=<PowBackward1>)
#
# LYS190B
# 10.4915
# tensor(9.7195, grad_fn=<PowBackward1>)
#
# GLU197B
# 4.41136
# tensor(4.2081, grad_fn=<PowBackward1>)
#
# TYR198B
# 11.1961
# tensor(8.1164, grad_fn=<PowBackward1>)
#
# LYS208B
# 11.1694
# tensor(10.2240, grad_fn=<PowBackward1>)
#
# GLU5A
# 2.25882
# tensor(6.2832, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.30527
# tensor(6.6061, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.34365
# tensor(9.4001, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4696
# tensor(7.3521, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.54005
# tensor(6.2265, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.56832
# tensor(3.3946, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.58891
# tensor(10.8651, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.88935
# tensor(3.4992, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8792
# tensor(12.8928, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.46405
# tensor(6.9471, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.2631200000000002
# tensor(5.5866, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.32242
# tensor(5.0475, grad_fn=<PowBackward1>)
#
# LYS43A
# 12.0184
# tensor(10.7158, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.70955
# tensor(3.9550, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.1675
# tensor(9.7231, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52923
# tensor(9.6711, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.8337
# tensor(14.7766, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.71395
# tensor(5.4309, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.3791
# tensor(4.8969, grad_fn=<PowBackward1>)
#
# LYS57A
# 11.2713
# tensor(8.8783, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.25727
# tensor(4.8742, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.16063
# tensor(2.4488, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4527
# tensor(12.9470, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.4527
# tensor(9.9371, grad_fn=<PowBackward1>)
#
# HIS65A
# 5.11776
# tensor(9.9650, grad_fn=<PowBackward1>)
#
# LYS78A
# 11.748
# tensor(10.6459, grad_fn=<PowBackward1>)
#
# LYS79A
# 11.4699
# tensor(9.0459, grad_fn=<PowBackward1>)
#
# LYS80A
# 11.4699
# tensor(9.8037, grad_fn=<PowBackward1>)
#
# HIS82A
# 5.30687
# tensor(8.2070, grad_fn=<PowBackward1>)
#
# HIS83A
# 5.30687
# tensor(13.0846, grad_fn=<PowBackward1>)
#
# GLU84A
# 2.66977
# tensor(4.8579, grad_fn=<PowBackward1>)
#
# GLU86A
# 2.17203
# tensor(3.2778, grad_fn=<PowBackward1>)
#
# LYS88A
# 10.6615
# tensor(10.6528, grad_fn=<PowBackward1>)
#
# HIS94A
# 5.22698
# tensor(6.3855, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.3312
# tensor(16.9939, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.59868
# tensor(8.2798, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9383
# tensor(8.4637, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.1126
# tensor(12.4438, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.5428
# tensor(11.0271, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6996599999999997
# tensor(4.3504, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.5291799999999998
# tensor(5.2618, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.9911
# tensor(11.3081, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.74408
# tensor(9.5611, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.10426
# tensor(8.2837, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.63867
# tensor(1.3890, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.3455
# tensor(13.5458, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.6754300000000004
# tensor(5.5755, grad_fn=<PowBackward1>)
#
# LYS141A
# 9.825389999999999
# tensor(7.4732, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.7921199999999999
# tensor(4.7406, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.148
# tensor(14.8092, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0179
# tensor(13.9239, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5509
# tensor(9.2319, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.8077699999999997
# tensor(4.3932, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4038
# tensor(11.8524, grad_fn=<PowBackward1>)
#
# finished one round
# GLU5A
# 2.17026
# tensor(4.3499, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.11289
# tensor(5.4609, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.316330000000001
# tensor(5.8903, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4738
# tensor(12.1125, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.5851599999999997
# tensor(2.9869, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.24728
# tensor(1.3750, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.51429
# tensor(6.3332, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.83166
# tensor(1.7062, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8763
# tensor(10.1351, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.323189999999999
# tensor(9.3767, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.28936
# tensor(4.0316, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.22865
# tensor(5.0539, grad_fn=<PowBackward1>)
#
# LYS43A
# 11.9456
# tensor(8.9210, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.8055
# tensor(1.0681, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.2767
# tensor(9.1143, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52289
# tensor(4.6928, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.7983
# tensor(11.4232, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.33478
# tensor(3.5140, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.27515
# tensor(4.3632, grad_fn=<PowBackward1>)
#
# LYS57A
# 11.129000000000001
# tensor(8.9815, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.6525199999999995
# tensor(2.9419, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.50623
# tensor(2.9528, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4535
# tensor(10.1189, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.4535
# tensor(12.9991, grad_fn=<PowBackward1>)
#
# LYS78A
# 11.5737
# tensor(11.2747, grad_fn=<PowBackward1>)
#
# LYS79A
# 11.5478
# tensor(11.2153, grad_fn=<PowBackward1>)
#
# LYS80A
# 11.5478
# tensor(8.7868, grad_fn=<PowBackward1>)
#
# HIS82A
# 5.54
# tensor(11.1870, grad_fn=<PowBackward1>)
#
# HIS83A
# 5.54
# tensor(7.1485, grad_fn=<PowBackward1>)
#
# GLU84A
# 2.61539
# tensor(4.7720, grad_fn=<PowBackward1>)
#
# GLU86A
# 2.36996
# tensor(3.9938, grad_fn=<PowBackward1>)
#
# LYS88A
# 10.6318
# tensor(16.0588, grad_fn=<PowBackward1>)
#
# HIS94A
# 5.422999999999999
# tensor(7.2516, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.1679
# tensor(15.4025, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.688680000000001
# tensor(8.0148, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9206
# tensor(10.9870, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.088
# tensor(8.4228, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.603
# tensor(8.5860, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6550599999999998
# tensor(3.8741, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.99917
# tensor(2.6001, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.94645
# tensor(8.1693, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.79091
# tensor(6.5622, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.05922
# tensor(4.4653, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.6458800000000005
# tensor(1.0838, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.4912
# tensor(8.3360, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.7402599999999997
# tensor(3.3536, grad_fn=<PowBackward1>)
#
# LYS141A
# 10.1161
# tensor(11.8381, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.47553900000000004
# tensor(2.5721, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.22
# tensor(11.9129, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0124
# tensor(9.5454, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5581
# tensor(12.0036, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.79943
# tensor(4.6570, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4895
# tensor(10.3729, grad_fn=<PowBackward1>)
#
# GLU5A
# 3.6048699999999996
# tensor(4.6103, grad_fn=<PowBackward1>)
#
# ASP10A
# 1.3983299999999999
# tensor(1.3747, grad_fn=<PowBackward1>)
#
# GLU11A
# 4.21061
# tensor(2.9484, grad_fn=<PowBackward1>)
#
# LYS16A
# 10.2553
# tensor(8.3818, grad_fn=<PowBackward1>)
#
# TYR18A
# 11.1976
# tensor(8.2921, grad_fn=<PowBackward1>)
#
# LYS19A
# 11.0319
# tensor(11.2855, grad_fn=<PowBackward1>)
#
# ASP20A
# 2.89969
# tensor(1.1633, grad_fn=<PowBackward1>)
#
# GLU22A
# 3.00215
# tensor(3.1734, grad_fn=<PowBackward1>)
#
# TYR24A
# 10.3155
# tensor(10.8278, grad_fn=<PowBackward1>)
#
# TYR25A
# 8.89904
# tensor(15.6845, grad_fn=<PowBackward1>)
#
# HIS31A
# 7.8168
# tensor(8.6099, grad_fn=<PowBackward1>)
#
# LYS35A
# 0.9233041952391611
# tensor(10.9767, grad_fn=<PowBackward1>)
#
# ASP43CA
# -0.4219535920047102
# tensor(1.7259, grad_fn=<PowBackward1>)
#
# LYS46A
# 0.2580780972279345
# tensor(12.8110, grad_fn=<PowBackward1>)
#
# GLU48A
# -0.06754868842738845
# tensor(4.0049, grad_fn=<PowBackward1>)
#
# ASP50A
# 1.7510052183781324
# tensor(2.4799, grad_fn=<PowBackward1>)
#
# LYS51A
# -0.04819161621559949
# tensor(12.6006, grad_fn=<PowBackward1>)
#
# LYS63A
# 1.2571899142905274
# tensor(13.8221, grad_fn=<PowBackward1>)
#
# ASP64A
# -0.575202044738755
# tensor(1.4473, grad_fn=<PowBackward1>)
#
# GLU65A
# 4.07334
# tensor(2.9936, grad_fn=<PowBackward1>)
#
# GLU67A
# 0.6976180393870018
# tensor(5.5171, grad_fn=<PowBackward1>)
#
# LYS68A
# 2.6262851180264333
# tensor(10.0431, grad_fn=<PowBackward1>)
#
# ASP73A
# 3.1071299999999997
# tensor(1.2813, grad_fn=<PowBackward1>)
#
# ASP75A
# -0.24734825436538285
# tensor(1.8241, grad_fn=<PowBackward1>)
#
# LYS86A
# 11.1797
# tensor(10.6439, grad_fn=<PowBackward1>)
#
# LYS88A
# 0.5894019837680343
# tensor(12.0808, grad_fn=<PowBackward1>)
#
# TYR91A
# -0.40164142831595584
# tensor(8.4434, grad_fn=<PowBackward1>)
#
# ASP92A
# 1.05585
# tensor(2.1198, grad_fn=<PowBackward1>)
#
# ASP95A
# -1.1939816671833086
# tensor(1.4319, grad_fn=<PowBackward1>)
#
# GLU111A
# 0.7322155377178244
# tensor(4.3238, grad_fn=<PowBackward1>)
#
# LYS127A
# -0.3750848052084507
# tensor(9.8194, grad_fn=<PowBackward1>)
#
# ASP130A
# -0.4141675660982062
# tensor(1.0742, grad_fn=<PowBackward1>)
#
# GLU131A
# 0.6228937223693969
# tensor(3.9731, grad_fn=<PowBackward1>)
#
# LYS138A
# -0.45137758288272994
# tensor(11.1091, grad_fn=<PowBackward1>)
#
# TYR142A
# -0.7307968747286131
# tensor(12.1751, grad_fn=<PowBackward1>)
#
# LYS150A
# 0.2851871871290518
# tensor(9.5047, grad_fn=<PowBackward1>)
#
# ASP162A
# -0.46308146327018074
# tensor(1.5980, grad_fn=<PowBackward1>)
#
# TYR164A
# -1.0313596464254735
# tensor(12.7751, grad_fn=<PowBackward1>)
#
# LYS165A
# 0.05204259865176685
# tensor(12.6995, grad_fn=<PowBackward1>)
#
# TYR3A
# 11.3108
# tensor(10.4308, grad_fn=<PowBackward1>)
#
# TYR7A
# 9.66513
# tensor(9.7618, grad_fn=<PowBackward1>)
#
# CYS14A
# 12.3283
# tensor(1.1860, grad_fn=<PowBackward1>)
#
# ASP23A
# 1.6541299999999999
# tensor(1.2856, grad_fn=<PowBackward1>)
#
# LYS29A
# 11.1225
# tensor(11.3527, grad_fn=<PowBackward1>)
#
# GLU30A
# 1.8763900000000002
# tensor(3.6897, grad_fn=<PowBackward1>)
#
# GLU31A
# 3.491
# tensor(3.9474, grad_fn=<PowBackward1>)
#
# GLU36A
# 4.053640000000001
# tensor(4.1135, grad_fn=<PowBackward1>)
#
# GLU40A
# 3.83331
# tensor(3.0617, grad_fn=<PowBackward1>)
#
# LYS44A
# 10.5261
# tensor(9.5121, grad_fn=<PowBackward1>)
#
# CYS47A
# 10.7954
# tensor(1.4398, grad_fn=<PowBackward1>)
#
# TYR49A
# 13.3563
# tensor(7.0534, grad_fn=<PowBackward1>)
#
# LYS54A
# 11.4235
# tensor(11.7903, grad_fn=<PowBackward1>)
#
# ASP57A
# 3.12194
# tensor(2.3442, grad_fn=<PowBackward1>)
#
# ASP59A
# 3.76229
# tensor(3.3024, grad_fn=<PowBackward1>)
#
# TYR63A
# 9.93648
# tensor(10.1699, grad_fn=<PowBackward1>)
#
# HIS71A
# 5.37399
# tensor(9.0640, grad_fn=<PowBackward1>)
#
# TYR79A
# 14.0334
# tensor(13.9398, grad_fn=<PowBackward1>)
#
# LYS81A
# 11.7278
# tensor(9.3621, grad_fn=<PowBackward1>)
#
# ASP82A
# 2.10677
# tensor(1.1796, grad_fn=<PowBackward1>)
#
# GLU85A
# 2.99493
# tensor(4.2988, grad_fn=<PowBackward1>)
#
# ASP90A
# -2.08976
# tensor(1.4170, grad_fn=<PowBackward1>)
#
# ASP94A
# 2.04279
# tensor(2.2739, grad_fn=<PowBackward1>)
#
# GLU97A
# 0.720119
# tensor(3.7665, grad_fn=<PowBackward1>)
#
# ASP98A
# 3.7668800000000005
# tensor(3.2061, grad_fn=<PowBackward1>)
#
# CYS101A
# 10.5065
# tensor(1.0182, grad_fn=<PowBackward1>)
#
# LYS102A
# 11.2875
# tensor(10.1401, grad_fn=<PowBackward1>)
#
# TYR103A
# 14.4342
# tensor(8.7554, grad_fn=<PowBackward1>)
#
# TYR108A
# 10.0359
# tensor(8.1418, grad_fn=<PowBackward1>)
#
# TYR111A
# 10.8418
# tensor(11.8959, grad_fn=<PowBackward1>)
#
# GLU112A
# 1.77688
# tensor(2.5967, grad_fn=<PowBackward1>)
#
# LYS115A
# 12.3084
# tensor(13.0443, grad_fn=<PowBackward1>)
#
# ASP116A
# 3.5621
# tensor(1.9830, grad_fn=<PowBackward1>)
#
# ASP117A
# 3.24708
# tensor(1.4842, grad_fn=<PowBackward1>)
#
# TYR118A
# 11.1035
# tensor(9.5051, grad_fn=<PowBackward1>)
#
# LYS120A
# 11.0595
# tensor(12.6270, grad_fn=<PowBackward1>)
#
# LYS127A
# 10.463
# tensor(9.4897, grad_fn=<PowBackward1>)
#
# GLU130A
# 2.8519799999999997
# tensor(3.7202, grad_fn=<PowBackward1>)
#
# LYS140A
# 10.3472
# tensor(10.7032, grad_fn=<PowBackward1>)
#
# ASP146A
# 3.68194
# tensor(1.3222, grad_fn=<PowBackward1>)
#
# ASP152A
# 2.24571
# tensor(1.5397, grad_fn=<PowBackward1>)
#
# TYR153A
# 13.6518
# tensor(9.9304, grad_fn=<PowBackward1>)
#
# ASP157A
# 2.7138299999999997
# tensor(1.1036, grad_fn=<PowBackward1>)
#
# HIS162A
# 5.78009
# tensor(7.2695, grad_fn=<PowBackward1>)
#
# GLU163A
# 4.02044
# tensor(4.5305, grad_fn=<PowBackward1>)
#
# CYS169A
# 12.177999999999999
# tensor(2.1698, grad_fn=<PowBackward1>)
#
# ASP171A
# 4.0267800000000005
# tensor(1.7645, grad_fn=<PowBackward1>)
#
# TYR179A
# 16.7491
# tensor(13.3893, grad_fn=<PowBackward1>)
#
# LYS188A
# 10.5335
# tensor(9.9409, grad_fn=<PowBackward1>)
#
# LYS190A
# 10.5017
# tensor(12.2956, grad_fn=<PowBackward1>)
#
# GLU197A
# 4.41164
# tensor(4.4474, grad_fn=<PowBackward1>)
#
# TYR198A
# 11.2606
# tensor(9.0030, grad_fn=<PowBackward1>)
#
# LYS208A
# 11.1899
# tensor(8.5015, grad_fn=<PowBackward1>)
#
# TYR3B
# 11.3018
# tensor(12.5385, grad_fn=<PowBackward1>)
#
# TYR7B
# 9.698139999999999
# tensor(10.2315, grad_fn=<PowBackward1>)
#
# CYS14B
# 12.367
# tensor(1.8681, grad_fn=<PowBackward1>)
#
# ASP23B
# 1.54906
# tensor(1.2410, grad_fn=<PowBackward1>)
#
# LYS29B
# 11.1642
# tensor(10.3853, grad_fn=<PowBackward1>)
#
# GLU30B
# 1.9062700000000001
# tensor(3.1145, grad_fn=<PowBackward1>)
#
# GLU31B
# 3.4797599999999997
# tensor(5.8735, grad_fn=<PowBackward1>)
#
# GLU36B
# 4.033440000000001
# tensor(5.0111, grad_fn=<PowBackward1>)
#
# GLU40B
# 3.8428
# tensor(2.3832, grad_fn=<PowBackward1>)
#
# LYS44B
# 10.3911
# tensor(10.0811, grad_fn=<PowBackward1>)
#
# CYS47B
# 10.8956
# tensor(1.0309, grad_fn=<PowBackward1>)
#
# TYR49B
# 13.3665
# tensor(10.8822, grad_fn=<PowBackward1>)
#
# LYS54B
# 11.4268
# tensor(10.2220, grad_fn=<PowBackward1>)
#
# ASP57B
# 3.14929
# tensor(1.3839, grad_fn=<PowBackward1>)
#
# ASP59B
# 3.75998
# tensor(1.4689, grad_fn=<PowBackward1>)
#
# TYR63B
# 10.0447
# tensor(10.4483, grad_fn=<PowBackward1>)
#
# HIS71B
# 5.376519999999999
# tensor(9.8096, grad_fn=<PowBackward1>)
#
# TYR79B
# 14.1107
# tensor(9.3454, grad_fn=<PowBackward1>)
#
# LYS81B
# 11.6971
# tensor(9.0464, grad_fn=<PowBackward1>)
#
# ASP82B
# 2.10338
# tensor(2.8070, grad_fn=<PowBackward1>)
#
# GLU85B
# 3.0055
# tensor(4.9389, grad_fn=<PowBackward1>)
#
# ASP90B
# -1.4355200000000001
# tensor(1.9881, grad_fn=<PowBackward1>)
#
# ASP94B
# 2.08924
# tensor(2.3836, grad_fn=<PowBackward1>)
#
# GLU97B
# 0.709659
# tensor(3.5928, grad_fn=<PowBackward1>)
#
# ASP98B
# 3.46987
# tensor(1.7011, grad_fn=<PowBackward1>)
#
# CYS101B
# 10.4488
# tensor(1.6119, grad_fn=<PowBackward1>)
#
# LYS102B
# 11.1985
# tensor(7.7126, grad_fn=<PowBackward1>)
#
# TYR103B
# 14.3269
# tensor(11.1055, grad_fn=<PowBackward1>)
#
# TYR108B
# 9.863719999999999
# tensor(12.4468, grad_fn=<PowBackward1>)
#
# TYR111B
# 10.9655
# tensor(8.1703, grad_fn=<PowBackward1>)
#
# GLU112B
# 1.7390599999999998
# tensor(4.8289, grad_fn=<PowBackward1>)
#
# LYS115B
# 12.3262
# tensor(10.9633, grad_fn=<PowBackward1>)
#
# ASP116B
# 3.56744
# tensor(1.5186, grad_fn=<PowBackward1>)
#
# ASP117B
# 3.2548
# tensor(1.0366, grad_fn=<PowBackward1>)
#
# TYR118B
# 11.110999999999999
# tensor(9.5361, grad_fn=<PowBackward1>)
#
# LYS120B
# 11.046
# tensor(12.6573, grad_fn=<PowBackward1>)
#
# LYS127B
# 10.4812
# tensor(8.2958, grad_fn=<PowBackward1>)
#
# GLU130B
# 2.83366
# tensor(5.2910, grad_fn=<PowBackward1>)
#
# LYS140B
# 10.3419
# tensor(14.2048, grad_fn=<PowBackward1>)
#
# ASP146B
# 3.70626
# tensor(1.0979, grad_fn=<PowBackward1>)
#
# ASP152B
# 2.26307
# tensor(2.1948, grad_fn=<PowBackward1>)
#
# TYR153B
# 13.8237
# tensor(10.6947, grad_fn=<PowBackward1>)
#
# ASP157B
# 2.70568
# tensor(1.5332, grad_fn=<PowBackward1>)
#
# HIS162B
# 5.72175
# tensor(4.3091, grad_fn=<PowBackward1>)
#
# GLU163B
# 4.07659
# tensor(4.0407, grad_fn=<PowBackward1>)
#
# CYS169B
# 12.1804
# tensor(1.2689, grad_fn=<PowBackward1>)
#
# ASP171B
# 4.01126
# tensor(1.4395, grad_fn=<PowBackward1>)
#
# TYR179B
# 16.6717
# tensor(11.2993, grad_fn=<PowBackward1>)
#
# LYS188B
# 10.5252
# tensor(11.5078, grad_fn=<PowBackward1>)
#
# LYS190B
# 10.4915
# tensor(8.6086, grad_fn=<PowBackward1>)
#
# GLU197B
# 4.41136
# tensor(7.0564, grad_fn=<PowBackward1>)
#
# TYR198B
# 11.1961
# tensor(9.2770, grad_fn=<PowBackward1>)
#
# LYS208B
# 11.1694
# tensor(11.1635, grad_fn=<PowBackward1>)
#
# GLU5A
# 2.25882
# tensor(3.8677, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.30527
# tensor(4.8449, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.34365
# tensor(7.8395, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4696
# tensor(7.5125, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.54005
# tensor(5.5280, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.56832
# tensor(2.8546, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.58891
# tensor(7.5210, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.88935
# tensor(1.8428, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8792
# tensor(11.0307, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.46405
# tensor(4.7778, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.2631200000000002
# tensor(4.3726, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.32242
# tensor(5.2652, grad_fn=<PowBackward1>)
#
# LYS43A
# 12.0184
# tensor(10.0015, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.70955
# tensor(4.6695, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.1675
# tensor(9.7695, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52923
# tensor(8.5560, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.8337
# tensor(9.0513, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.71395
# tensor(4.6424, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.3791
# tensor(5.1933, grad_fn=<PowBackward1>)
#
# LYS57A
# 11.2713
# tensor(12.4756, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.25727
# tensor(3.7141, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.16063
# tensor(4.7894, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4527
# tensor(10.1208, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.
grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4895
# tensor(6.3259, grad_fn=<PowBackward1>)
#
# GLU5A
# 3.6048699999999996
# tensor(1.7514, grad_fn=<PowBackward1>)
#
# ASP10A
# 1.3983299999999999
# tensor(2.6727, grad_fn=<PowBackward1>)
#
# GLU11A
# 4.21061
# tensor(2.8038, grad_fn=<PowBackward1>)
#
# LYS16A
# 10.2553
# tensor(7.5916, grad_fn=<PowBackward1>)
#
# TYR18A
# 11.1976
# tensor(7.3092, grad_fn=<PowBackward1>)
#
# ...
#
# HIS94A
# 5.22698
# tensor(5.3020, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.3312
# tensor(9.9545, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.59868
# tensor(5.0822, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9383
# tensor(11.3489, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.1126
# tensor(9.9878, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.5428
# tensor(10.6246, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6996599999999997
# tensor(3.1841, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.5291799999999998
# tensor(2.8818, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.9911
# tensor(6.4565, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.74408
# tensor(5.3330, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.10426
# tensor(5.5919, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.63867
# tensor(1.9065, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.3455
# tensor(9.8245, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.6754300000000004
# tensor(2.7430, grad_fn=<PowBackward1>)
#
# LYS141A
# 9.825389999999999
# tensor(10.1196, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.7921199999999999
# tensor(2.1716, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.148
# tensor(10.9886, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0179
# tensor(9.4357, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5509
# tensor(10.5539, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.8077699999999997
# tensor(3.0675, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4038
# tensor(10.2161, grad_fn=<PowBackward1>)
#
# finished one round
# GLU5A
# 2.17026
# tensor(3.6317, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.11289
# tensor(3.2984, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.316330000000001
# tensor(5.3604, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4738
# tensor(10.7041, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.5851599999999997
# tensor(4.2932, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.24728
# tensor(3.6698, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.51429
# tensor(5.4448, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.83166
# tensor(3.1987, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8763
# tensor(11.4664, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.323189999999999
# tensor(6.1327, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.28936
# tensor(3.6991, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.22865
# tensor(3.4606, grad_fn=<PowBackward1>)
#
# LYS43A
# 11.9456
# tensor(11.2738, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.8055
# tensor(2.7118, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.2767
# tensor(10.3479, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52289
# tensor(5.9487, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.7983
# tensor(10.7745, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.33478
# tensor(3.4649, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.27515
# tensor(3.2198, grad_fn=<PowBackward1>)
#
# LYS57A
# 11.129000000000001
# tensor(11.1697, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.6525199999999995
# tensor(3.0683, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.50623
# tensor(2.6763, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4535
# tensor(11.3762, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.4535
# tensor(10.6975, grad_fn=<PowBackward1>)
#
# LYS78A
# 11.5737
# tensor(10.6106, grad_fn=<PowBackward1>)
#
# LYS79A
# 11.5478
# tensor(12.2516, grad_fn=<PowBackward1>)
#
# LYS80A
# 11.5478
# tensor(11.2217, grad_fn=<PowBackward1>)
#
# HIS82A
# 5.54
# tensor(6.0189, grad_fn=<PowBackward1>)
#
# HIS83A
# 5.54
# tensor(5.9642, grad_fn=<PowBackward1>)
#
# GLU84A
# 2.61539
# tensor(3.8062, grad_fn=<PowBackward1>)
#
# GLU86A
# 2.36996
# tensor(3.4099, grad_fn=<PowBackward1>)
#
# LYS88A
# 10.6318
# tensor(11.5683, grad_fn=<PowBackward1>)
#
# HIS94A
# 5.422999999999999
# tensor(5.3917, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.1679
# tensor(10.8290, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.688680000000001
# tensor(5.6585, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9206
# tensor(9.2270, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.088
# tensor(11.4817, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.603
# tensor(10.6438, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6550599999999998
# tensor(3.4973, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.99917
# tensor(3.3954, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.94645
# tensor(6.2458, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.79091
# tensor(6.1369, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.05922
# tensor(7.1042, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.6458800000000005
# tensor(2.3537, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.4912
# tensor(11.1637, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.7402599999999997
# tensor(3.9633, grad_fn=<PowBackward1>)
#
# LYS141A
# 10.1161
# tensor(10.2061, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.47553900000000004
# tensor(2.7324, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.22
# tensor(11.0196, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0124
# tensor(10.8743, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5581
# tensor(11.4112, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.79943
# tensor(3.4053, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4895
# tensor(9.6750, grad_fn=<PowBackward1>)
#
# GLU5A
# 3.6048699999999996
# tensor(3.5390, grad_fn=<PowBackward1>)
#
# ASP10A
# 1.3983299999999999
# tensor(3.2942, grad_fn=<PowBackward1>)
#
# GLU11A
# 4.21061
# tensor(3.7007, grad_fn=<PowBackward1>)
#
# LYS16A
# 10.2553
# tensor(11.7407, grad_fn=<PowBackward1>)
#
# TYR18A
# 11.1976
# tensor(10.8641, grad_fn=<PowBackward1>)
#
# LYS19A
# 11.0319
# tensor(11.0179, grad_fn=<PowBackward1>)
#
# ASP20A
# 2.89969
# tensor(2.2042, grad_fn=<PowBackward1>)
#
# GLU22A
# 3.00215
# tensor(3.8219, grad_fn=<PowBackward1>)
#
# TYR24A
# 10.3155
# tensor(11.1948, grad_fn=<PowBackward1>)
#
# TYR25A
# 8.89904
# tensor(10.3998, grad_fn=<PowBackward1>)
#
# HIS31A
# 7.8168
# tensor(5.9368, grad_fn=<PowBackward1>)
#
# LYS35A
# 1.3730890373223927
# tensor(10.7447, grad_fn=<PowBackward1>)
#
# ASP43CA
# 0.19904847377126308
# tensor(2.9459, grad_fn=<PowBackward1>)
#
# LYS46A
# -0.47773719661473696
# tensor(10.0397, grad_fn=<PowBackward1>)
#
# GLU48A
# -0.36965425881286973
# tensor(3.4641, grad_fn=<PowBackward1>)
#
# ASP50A
# -0.6622230797768883
# tensor(2.5678, grad_fn=<PowBackward1>)
#
# LYS51A
# -0.35746351804558246
# tensor(10.2181, grad_fn=<PowBackward1>)
#
# LYS63A
# 0.6740546967210831
# tensor(10.6027, grad_fn=<PowBackward1>)
#
# ASP64A
# -0.820751736367303
# tensor(2.3000, grad_fn=<PowBackward1>)
#
# GLU65A
# 4.07334
# tensor(3.9690, grad_fn=<PowBackward1>)
#
# GLU67A
# 0.6866308831971363
# tensor(4.0370, grad_fn=<PowBackward1>)
#
# LYS68A
# 1.9596801420664585
# tensor(10.7873, grad_fn=<PowBackward1>)
#
# ASP73A
# 3.1071299999999997
# tensor(2.7121, grad_fn=<PowBackward1>)
#
# ASP75A
# -0.3104326216973219
# tensor(2.4456, grad_fn=<PowBackward1>)
#
# LYS86A
# 11.1797
# tensor(11.2372, grad_fn=<PowBackward1>)
#
# LYS88A
# -0.08616362297405562
# tensor(11.0584, grad_fn=<PowBackward1>)
#
# TYR91A
# -0.03414494575938506
# tensor(10.7579, grad_fn=<PowBackward1>)
#
# ASP92A
# 1.05585
# tensor(3.5232, grad_fn=<PowBackward1>)
#
# ASP95A
# -0.15667174776647255
# tensor(3.1299, grad_fn=<PowBackward1>)
#
# GLU111A
# 0.3955130724001399
# tensor(4.0823, grad_fn=<PowBackward1>)
#
# LYS127A
# -1.085222520780101
# tensor(10.9909, grad_fn=<PowBackward1>)
#
# ASP130A
# 0.8879768968917547
# tensor(2.4631, grad_fn=<PowBackward1>)
#
# GLU131A
# -1.0913316575576033
# tensor(3.8393, grad_fn=<PowBackward1>)
#
# LYS138A
# 2.275825715999204
# tensor(11.7894, grad_fn=<PowBackward1>)
#
# TYR142A
# -0.4942893099086861
# tensor(11.9119, grad_fn=<PowBackward1>)
#
# LYS150A
# 0.890693508855233
# tensor(11.6608, grad_fn=<PowBackward1>)
#
# ASP162A
# -1.2934875847747689
# tensor(2.9391, grad_fn=<PowBackward1>)
#
# TYR164A
# -1.1011112447446019
# tensor(9.8976, grad_fn=<PowBackward1>)
#
# LYS165A
# -0.45844049594665054
# tensor(10.7255, grad_fn=<PowBackward1>)
#
# TYR3A
# 11.3108
# tensor(10.8942, grad_fn=<PowBackward1>)
#
# TYR7A
# 9.66513
# tensor(11.1413, grad_fn=<PowBackward1>)
#
# CYS14A
# 12.3283
# tensor(2.8284, grad_fn=<PowBackward1>)
#
# ASP23A
# 1.6541299999999999
# tensor(2.7457, grad_fn=<PowBackward1>)
#
# LYS29A
# 11.1225
# tensor(10.3928, grad_fn=<PowBackward1>)
#
# GLU30A
# 1.8763900000000002
# tensor(3.7192, grad_fn=<PowBackward1>)
#
# GLU31A
# 3.491
# tensor(3.6524, grad_fn=<PowBackward1>)
#
# GLU36A
# 4.053640000000001
# tensor(4.0237, grad_fn=<PowBackward1>)
#
# GLU40A
# 3.83331
# tensor(3.5979, grad_fn=<PowBackward1>)
#
# LYS44A
# 10.5261
# tensor(11.8702, grad_fn=<PowBackward1>)
#
# CYS47A
# 10.7954
# tensor(2.6567, grad_fn=<PowBackward1>)
#
# TYR49A
# 13.3563
# tensor(10.6224, grad_fn=<PowBackward1>)
#
# LYS54A
# 11.4235
# tensor(11.3291, grad_fn=<PowBackward1>)
#
# ASP57A
# 3.12194
# tensor(2.4859, grad_fn=<PowBackward1>)
#
# ASP59A
# 3.76229
# tensor(2.7197, grad_fn=<PowBackward1>)
#
# TYR63A
# 9.93648
# tensor(9.3780, grad_fn=<PowBackward1>)
#
# HIS71A
# 5.37399
# tensor(6.4861, grad_fn=<PowBackward1>)
#
# TYR79A
# 14.0334
# tensor(10.4786, grad_fn=<PowBackward1>)
#
# LYS81A
# 11.7278
# tensor(10.4057, grad_fn=<PowBackward1>)
#
# ASP82A
# 2.10677
# tensor(2.6852, grad_fn=<PowBackward1>)
#
# GLU85A
# 2.99493
# tensor(3.4668, grad_fn=<PowBackward1>)
#
# ASP90A
# -2.08976
# tensor(2.5686, grad_fn=<PowBackward1>)
#
# ASP94A
# 2.04279
# tensor(2.7195, grad_fn=<PowBackward1>)
#
# GLU97A
# 0.720119
# tensor(3.4641, grad_fn=<PowBackward1>)
#
# ASP98A
# 3.7668800000000005
# tensor(2.9669, grad_fn=<PowBackward1>)
#
# CYS101A
# 10.5065
# tensor(1.9679, grad_fn=<PowBackward1>)
#
# LYS102A
# 11.2875
# tensor(10.7008, grad_fn=<PowBackward1>)
#
# TYR103A
# 14.4342
# tensor(10.4654, grad_fn=<PowBackward1>)
#
# TYR108A
# 10.0359
# tensor(10.7263, grad_fn=<PowBackward1>)
#
# TYR111A
# 10.8418
# tensor(9.9959, grad_fn=<PowBackward1>)
#
# GLU112A
# 1.77688
# tensor(3.6832, grad_fn=<PowBackward1>)
#
# LYS115A
# 12.3084
# tensor(10.4187, grad_fn=<PowBackward1>)
#
# ASP116A
# 3.5621
# tensor(2.7200, grad_fn=<PowBackward1>)
#
# ASP117A
# 3.24708
# tensor(2.7172, grad_fn=<PowBackward1>)
#
# TYR118A
# 11.1035
# tensor(9.5204, grad_fn=<PowBackward1>)
#
# LYS120A
# 11.0595
# tensor(10.5184, grad_fn=<PowBackward1>)
#
# LYS127A
# 10.463
# tensor(12.2146, grad_fn=<PowBackward1>)
#
# GLU130A
# 2.8519799999999997
# tensor(3.9846, grad_fn=<PowBackward1>)
#
# LYS140A
# 10.3472
# tensor(10.1742, grad_fn=<PowBackward1>)
#
# ASP146A
# 3.68194
# tensor(2.9008, grad_fn=<PowBackward1>)
#
# ASP152A
# 2.24571
# tensor(2.4656, grad_fn=<PowBackward1>)
#
# TYR153A
# 13.6518
# tensor(9.8319, grad_fn=<PowBackward1>)
#
# ASP157A
# 2.7138299999999997
# tensor(2.2956, grad_fn=<PowBackward1>)
#
# HIS162A
# 5.78009
# tensor(5.8450, grad_fn=<PowBackward1>)
#
# GLU163A
# 4.02044
# tensor(3.4549, grad_fn=<PowBackward1>)
#
# CYS169A
# 12.177999999999999
# tensor(2.1462, grad_fn=<PowBackward1>)
#
# ASP171A
# 4.0267800000000005
# tensor(3.2334, grad_fn=<PowBackward1>)
#
# TYR179A
# 16.7491
# tensor(10.5243, grad_fn=<PowBackward1>)
#
# LYS188A
# 10.5335
# tensor(10.2435, grad_fn=<PowBackward1>)
#
# LYS190A
# 10.5017
# tensor(11.8470, grad_fn=<PowBackward1>)
#
# GLU197A
# 4.41164
# tensor(3.4418, grad_fn=<PowBackward1>)
#
# TYR198A
# 11.2606
# tensor(10.9963, grad_fn=<PowBackward1>)
#
# LYS208A
# 11.1899
# tensor(10.3199, grad_fn=<PowBackward1>)
#
# TYR3B
# 11.3018
# tensor(9.8892, grad_fn=<PowBackward1>)
#
# TYR7B
# 9.698139999999999
# tensor(10.8824, grad_fn=<PowBackward1>)
#
# CYS14B
# 12.367
# tensor(2.2376, grad_fn=<PowBackward1>)
#
# ASP23B
# 1.54906
# tensor(2.7492, grad_fn=<PowBackward1>)
#
# LYS29B
# 11.1642
# tensor(11.3979, grad_fn=<PowBackward1>)
#
# GLU30B
# 1.9062700000000001
# tensor(3.7491, grad_fn=<PowBackward1>)
#
# GLU31B
# 3.4797599999999997
# tensor(3.5758, grad_fn=<PowBackward1>)
#
# GLU36B
# 4.033440000000001
# tensor(3.4757, grad_fn=<PowBackward1>)
#
# GLU40B
# 3.8428
# tensor(3.9954, grad_fn=<PowBackward1>)
#
# LYS44B
# 10.3911
# tensor(11.4985, grad_fn=<PowBackward1>)
#
# CYS47B
# 10.8956
# tensor(2.4366, grad_fn=<PowBackward1>)
#
# TYR49B
# 13.3665
# tensor(9.5317, grad_fn=<PowBackward1>)
#
# LYS54B
# 11.4268
# tensor(11.4794, grad_fn=<PowBackward1>)
#
# ASP57B
# 3.14929
# tensor(2.4135, grad_fn=<PowBackward1>)
#
# ASP59B
# 3.75998
# tensor(3.0564, grad_fn=<PowBackward1>)
#
# TYR63B
# 10.0447
# tensor(10.3937, grad_fn=<PowBackward1>)
#
# HIS71B
# 5.376519999999999
# tensor(6.2791, grad_fn=<PowBackward1>)
#
# TYR79B
# 14.1107
# tensor(9.5669, grad_fn=<PowBackward1>)
#
# LYS81B
# 11.6971
# tensor(11.6358, grad_fn=<PowBackward1>)
#
# ASP82B
# 2.10338
# tensor(2.8047, grad_fn=<PowBackward1>)
#
# GLU85B
# 3.0055
# tensor(3.3712, grad_fn=<PowBackward1>)
#
# ASP90B
# -1.4355200000000001
# tensor(3.0142, grad_fn=<PowBackward1>)
#
# ASP94B
# 2.08924
# tensor(2.5626, grad_fn=<PowBackward1>)
#
# GLU97B
# 0.709659
# tensor(3.4055, grad_fn=<PowBackward1>)
#
# ASP98B
# 3.46987
# tensor(2.6935, grad_fn=<PowBackward1>)
#
# CYS101B
# 10.4488
# tensor(1.9536, grad_fn=<PowBackward1>)
#
# LYS102B
# 11.1985
# tensor(11.1486, grad_fn=<PowBackward1>)
#
# TYR103B
# 14.3269
# tensor(11.1740, grad_fn=<PowBackward1>)
#
# TYR108B
# 9.863719999999999
# tensor(11.1951, grad_fn=<PowBackward1>)
#
# TYR111B
# 10.9655
# tensor(10.6537, grad_fn=<PowBackward1>)
#
# GLU112B
# 1.7390599999999998
# tensor(3.7327, grad_fn=<PowBackward1>)
#
# LYS115B
# 12.3262
# tensor(10.3461, grad_fn=<PowBackward1>)
#
# ASP116B
# 3.56744
# tensor(2.8654, grad_fn=<PowBackward1>)
#
# ASP117B
# 3.2548
# tensor(2.8286, grad_fn=<PowBackward1>)
#
# TYR118B
# 11.110999999999999
# tensor(10.5503, grad_fn=<PowBackward1>)
#
# LYS120B
# 11.046
# tensor(10.8613, grad_fn=<PowBackward1>)
#
# LYS127B
# 10.4812
# tensor(10.1572, grad_fn=<PowBackward1>)
#
# GLU130B
# 2.83366
# tensor(3.6257, grad_fn=<PowBackward1>)
#
# LYS140B
# 10.3419
# tensor(10.9189, grad_fn=<PowBackward1>)
#
# ASP146B
# 3.70626
# tensor(2.5490, grad_fn=<PowBackward1>)
#
# ASP152B
# 2.26307
# tensor(2.2357, grad_fn=<PowBackward1>)
#
# TYR153B
# 13.8237
# tensor(10.7545, grad_fn=<PowBackward1>)
#
# ASP157B
# 2.70568
# tensor(2.3012, grad_fn=<PowBackward1>)
#
# HIS162B
# 5.72175
# tensor(5.4786, grad_fn=<PowBackward1>)
#
# GLU163B
# 4.07659
# tensor(3.7260, grad_fn=<PowBackward1>)
#
# CYS169B
# 12.1804
# tensor(2.6330, grad_fn=<PowBackward1>)
#
# ASP171B
# 4.01126
# tensor(2.6029, grad_fn=<PowBackward1>)
#
# TYR179B
# 16.6717
# tensor(10.1112, grad_fn=<PowBackward1>)
#
# LYS188B
# 10.5252
# tensor(11.0086, grad_fn=<PowBackward1>)
#
# LYS190B
# 10.4915
# tensor(10.7994, grad_fn=<PowBackward1>)
#
# GLU197B
# 4.41136
# tensor(2.7874, grad_fn=<PowBackward1>)
#
# TYR198B
# 11.1961
# tensor(9.9240, grad_fn=<PowBackward1>)
#
# LYS208B
# 11.1694
# tensor(10.6154, grad_fn=<PowBackward1>)
#
# GLU5A
# 2.25882
# tensor(3.2787, grad_fn=<PowBackward1>)
#
# GLU7A
# 2.30527
# tensor(3.3919, grad_fn=<PowBackward1>)
#
# HIS13A
# 6.34365
# tensor(5.7065, grad_fn=<PowBackward1>)
#
# LYS17A
# 10.4696
# tensor(11.3823, grad_fn=<PowBackward1>)
#
# GLU19A
# 2.54005
# tensor(3.8332, grad_fn=<PowBackward1>)
#
# ASP21A
# 2.56832
# tensor(2.8655, grad_fn=<PowBackward1>)
#
# HIS25A
# 1.58891
# tensor(5.6209, grad_fn=<PowBackward1>)
#
# ASP28A
# 2.88935
# tensor(3.1633, grad_fn=<PowBackward1>)
#
# LYS35A
# 10.8792
# tensor(11.1857, grad_fn=<PowBackward1>)
#
# HIS37A
# 7.46405
# tensor(6.4866, grad_fn=<PowBackward1>)
#
# GLU39A
# 3.2631200000000002
# tensor(3.6412, grad_fn=<PowBackward1>)
#
# GLU42A
# 4.32242
# tensor(4.0191, grad_fn=<PowBackward1>)
#
# LYS43A
# 12.0184
# tensor(11.7560, grad_fn=<PowBackward1>)
#
# ASP45A
# 2.70955
# tensor(2.8713, grad_fn=<PowBackward1>)
#
# LYS48A
# 11.1675
# tensor(11.8265, grad_fn=<PowBackward1>)
#
# HIS49A
# 5.52923
# tensor(6.1564, grad_fn=<PowBackward1>)
#
# LYS51A
# 10.8337
# tensor(11.4876, grad_fn=<PowBackward1>)
#
# GLU53A
# 2.71395
# tensor(3.3373, grad_fn=<PowBackward1>)
#
# GLU55A
# 3.3791
# tensor(3.3716, grad_fn=<PowBackward1>)
#
# LYS57A
# 11.2713
# tensor(10.0882, grad_fn=<PowBackward1>)
#
# GLU60A
# 3.25727
# tensor(3.7695, grad_fn=<PowBackward1>)
#
# ASP61A
# 2.16063
# tensor(2.4236, grad_fn=<PowBackward1>)
#
# LYS63A
# 10.4527
# tensor(11.9348, grad_fn=<PowBackward1>)
#
# LYS64A
# 10.4527
# tensor(10.4486, grad_fn=<PowBackward1>)
#
# HIS65A
# 5.11776
# tensor(5.6299, grad_fn=<PowBackward1>)
#
# LYS78A
# 11.748
# tensor(11.3139, grad_fn=<PowBackward1>)
#
# LYS79A
# 11.4699
# tensor(10.2427, grad_fn=<PowBackward1>)
#
# LYS80A
# 11.4699
# tensor(12.1641, grad_fn=<PowBackward1>)
#
# HIS82A
# 5.30687
# tensor(5.4893, grad_fn=<PowBackward1>)
#
# HIS83A
# 5.30687
# tensor(6.7244, grad_fn=<PowBackward1>)
#
# GLU84A
# 2.66977
# tensor(3.9809, grad_fn=<PowBackward1>)
#
# GLU86A
# 2.17203
# tensor(3.2308, grad_fn=<PowBackward1>)
#
# LYS88A
# 10.6615
# tensor(10.7654, grad_fn=<PowBackward1>)
#
# HIS94A
# 5.22698
# tensor(6.6505, grad_fn=<PowBackward1>)
#
# LYS97A
# 10.3312
# tensor(11.0901, grad_fn=<PowBackward1>)
#
# HIS98A
# 5.59868
# tensor(5.6761, grad_fn=<PowBackward1>)
#
# LYS99A
# 10.9383
# tensor(10.9794, grad_fn=<PowBackward1>)
#
# LYS103A
# 11.1126
# tensor(11.5390, grad_fn=<PowBackward1>)
#
# TYR104A
# 10.5428
# tensor(10.0495, grad_fn=<PowBackward1>)
#
# GLU106A
# 3.6996599999999997
# tensor(3.2719, grad_fn=<PowBackward1>)
#
# GLU110A
# 2.5291799999999998
# tensor(3.9387, grad_fn=<PowBackward1>)
#
# HIS114A
# 5.9911
# tensor(6.2979, grad_fn=<PowBackward1>)
#
# HIS117A
# 6.74408
# tensor(5.0977, grad_fn=<PowBackward1>)
#
# HIS120A
# 5.10426
# tensor(6.2051, grad_fn=<PowBackward1>)
#
# ASP127A
# 3.63867
# tensor(2.5325, grad_fn=<PowBackward1>)
#
# LYS134A
# 11.3455
# tensor(10.8498, grad_fn=<PowBackward1>)
#
# GLU137A
# 3.6754300000000004
# tensor(4.2977, grad_fn=<PowBackward1>)
#
# LYS141A
# 9.825389999999999
# tensor(11.6838, grad_fn=<PowBackward1>)
#
# ASP142A
# 0.7921199999999999
# tensor(2.4553, grad_fn=<PowBackward1>)
#
# LYS146A
# 11.148
# tensor(10.2573, grad_fn=<PowBackward1>)
#
# TYR147A
# 14.0179
# tensor(10.6653, grad_fn=<PowBackward1>)
#
# LYS148A
# 10.5509
# tensor(11.5234, grad_fn=<PowBackward1>)
#
# GLU149A
# 3.8077699999999997
# tensor(3.1293, grad_fn=<PowBackward1>)
#
# TYR152A
# 11.4038
# tensor(10.8286, grad_fn=<PowBackward1>)

# %%
y[0]
# Out:
# tensor([[-0.9319, -0.1476],
#         [ 2.1887, -0.7530],
#         [ 2.1853, -0.4190],
#         [ 2.1769, -0.3604],
#         [ 2.1727, -0.8427],
#         [ 2.2190, -0.9283],
#         [ 2.1913, -0.9812],
#         [ 2.2311, -1.0537],
#         [ 2.3036, -0.8874],
#         [ 2.2012, -0.9755],
#         [ 2.2877, -0.8489],
#         [ 2.3444, -0.8469],
#         [ 2.1948, -1.0604],
#         [ 2.2086, -1.0445],
#         [ 2.2560, -0.0764],
#         [ 2.1915, -0.6440],
#         [ 2.2023, -1.0191],
#         [ 2.3597, -0.9850],
#         [ 2.2669,  0.6729],
#         [ 2.1871, -1.1155],
#         [ 1.5785,  0.5205]], grad_fn=<SelectBackward0>)

# %%
torch.matmul(torch.mean(y[0],dim=1),torch.mean(y[0],dim=1))
# Out:
# tensor(12.7563, grad_fn=<DotBackward0>)

# %%
B = PositionalEncoding(1)
m=B(torch.sum(torch.mean(y[0],dim=1)).unsqueeze(2)
mha2= SimpleMultiheadAttention(1,1)

# %%
feat=torch.tensor([2,1])
PositionalEncoding(1)(feat)
#S#impleMultiheadAttention(2,1)(feat.unsqueeze(1))

#use mean and sum as input,to reduce each node reduced to 1 node, 2 dims
u = torch.tensor([[pred], [3.172]])
mha4= SimpleMultiheadAttention(2,1)
g = PositionalEncoding(2)(u)
n = mha4(g)
n
# Out:
# tensor([[[-1.3739,  7.0294],
#          [-0.4717,  2.4282]],
#
#         [[ 1.0588,  3.4807],
#          [-0.4965,  2.4413]]], grad_fn=<AddBackward0>)

# %%
pred
label
# Out:
# 11.4038

# %%
B(torch.mean(y[0],dim=1))
# Out:
# tensor([[[-0.5386,  0.2746,  0.2121, -1.5067,  0.2118, -0.0281,  0.6355,
#           -0.3063,  0.1980,  0.3358, -0.0419,  0.6330,  0.5565,  0.5108,
#            0.0000, -0.4346, -0.5574, -0.0000, -0.6776,  0.2749,  0.0000]],
#
#         [[ 0.3964,  1.2096,  1.1471, -0.5717,  1.1468,  0.9068,  1.5705,
#            0.6287,  1.1330,  1.2707,  0.8931,  1.5679,  1.4915,  1.4458,
#            1.0574,  0.5003,  0.0000,  0.3952,  0.2573,  1.2098,  0.0000]],
#
#         [[ 0.4717,  0.0000,  1.2224, -0.4964,  0.0000,  0.9822,  1.6458,
#            0.7040,  1.2083,  0.0000,  0.9685,  0.0000,  1.5669,  1.5212,
#            1.1328,  0.5757,  0.4530,  0.4705,  0.3327,  1.2852,  1.1868]],
#
#         [[-0.3818,  0.4314,  0.3689, -1.3499,  0.3686,  0.1287,  0.7923,
#           -0.1495,  0.0000,  0.0000,  0.1149,  0.7898,  0.7133,  0.6676,
#            0.2793, -0.0000, -0.4006, -0.3830, -0.5208,  0.4317,  0.3333]],
#
#         [[-1.3795, -0.5663, -0.6288, -2.3476, -0.6291, -0.8690, -0.2054,
#           -1.1472, -0.6429, -0.5051, -0.8828, -0.2079, -0.2844, -0.3301,
#           -0.7184, -1.2755, -1.3983, -1.3807, -1.5185, -0.5660, -0.6644]],
#
#         [[-1.6041, -0.7909, -0.8534, -2.5722, -0.8537, -1.0936, -0.4300,
#           -1.3718, -0.8675, -0.7297, -1.1073, -0.4325, -0.5090, -0.5546,
#           -0.9430, -1.5001, -1.6228, -1.6053, -1.7431, -0.7906, -0.8890]],
#
#         [[-0.8491, -0.0358, -0.0983, -1.8172, -0.0987, -0.3386,  0.3250,
#           -0.6168, -0.1125,  0.0253, -0.3523,  0.3225,  0.2461,  0.2004,
#           -0.1880, -0.7451, -0.8678, -0.8503, -0.9881, -0.0356, -0.1339]],
#
#         [[ 0.1914,  0.0000,  0.9421, -0.7767,  0.9418,  0.7019,  1.3655,
#            0.4237,  0.9280,  1.0657,  0.6881,  1.3629,  0.0000,  1.2408,
#            0.8525,  0.2953,  0.0000,  0.1902,  0.0524,  0.0000,  0.9065]],
#
#         [[ 0.5607,  1.3739,  1.3114, -0.4074,  1.3111,  0.0000,  1.7348,
#            0.7930,  1.2973,  1.4351,  1.0574,  1.7322,  1.6558,  1.6101,
#            0.0000,  0.6646,  0.5419,  0.5595,  0.4217,  1.3742,  0.0000]],
#
#         [[-0.0807,  0.7325,  0.0000, -1.0488,  0.6697,  0.4298,  1.0934,
#            0.1516,  0.6559,  0.7937,  0.4160,  1.0909,  1.0144,  0.9687,
#            0.5804,  0.0233, -0.0995, -0.0819, -0.2197,  0.7328,  0.0000]],
#        grad_fn=<MulBackward0>)

# %%
torch.mean(y[0],dim=1)
# Out:
# tensor([-0.4847,  0.2472,  0.1909, -1.3560,  0.1906, -0.0253,  0.5719, -0.2757,
#          0.1782,  0.3022, -0.0377,  0.5697,  0.5009,  0.4597,  0.1102, -0.3912,
#         -0.5016, -0.4858, -0.6099,  0.2474,  0.1589], grad_fn=<MeanBackward1>)

# %%
np.log(3.4)
# Out:
# 1.2237754316221157

# %%
np.log(np.abs(1 + 67))
# Out:
# 4.219507705176107

# %%
y
label
torch.mean(y[0][17:])
label
# Out:
# 11.4038

# %%
10.5 + .8 + 2.4 / 3
# Out:
# 12.100000000000001

# %%
torch.max(torch.mean(output, dim=0))
y
# Out:
# tensor([[ 0.2337,  0.2968,  0.0480,  4.5044,  0.0468, 17.5079,  0.1077,  1.4653,
#           0.2014,  6.6987,  0.3193,  1.8857,  0.1864,  9.5172,  8.6554,  1.1121,
#           0.8656,  5.8812, 40.8738,  1.4486,  0.1704]], grad_fn=<PowBackward1>)

# %%
torch.mean(output, dim=-0)
# Out:
# tensor([[-1.9666, -2.7612, -1.1210, -6.5646, -3.7918, 10.5193, -2.6809, -3.7751,
#          -0.1082, -2.6251, -2.9264, -5.2189,  0.4194, -2.8971,  0.8069, -2.7505,
#          -1.6541, -0.9493, -3.4236, -1.0440,  2.4191, -0.6177]],
#        grad_fn=<MeanBackward1>)

# %%
torch.sum(output[0][0])/3

#output
# Out:
# tensor(-11.4382, grad_fn=<DivBackward0>)

# %%
torch.sum(output[6][0])
# Out:
# tensor(145.9846, grad_fn=<SumBackward0>)

# %%
residuals,vresiduals, ts,ps, es =[],[],[],[],[]
vresiduals, vts,vps, ves =[],[],[],[]
for i in range(nepochs):
    r = results[i]
    #print(r)
    
    e=[]
    for re in r:
        residuals.append(re[3] - re[2])
        ts.append(re[3])
        #ps.append(re[2])
        e.append(re[4])

    es.append(np.mean(e))

    V=vresults[i]
    e=[]
    #print(v)

    for v in V:
        vresiduals.append(v[3] - v[2])
        vts.append(v[3])
        vps.append(v[2])
        e.append(re[4])

    ves.append(np.mean(e))




plt.scatter(ts, residuals, alpha=1, label="train")
#plt.ylim(-20,20)
plt.axhline(y=0, color='r', linestyle='--')



plt.xlabel("True Values")
plt.ylabel("Residual (Predicted - True)")
#plt.title("5e, dim 2,depth 3, 2 nn, lr=.0001 wd=1, 50 tokens, dropout .6 \n dne = 13")
plt.title("egnn+multihead-attention + math \n 15epoch, 20 structures of only two varieties (99.9% sure) \n at least one variety with HEME \n 16T/4V split, labelless targets get random value \n weight decay 0.01, dropout 0.1 (att) and 0.05 (egnn), lr 0.001, dim2, depth3 \n")
plt.plot(es, color="g", marker="*")
plt.plot(ves, color="purple", marker="+", label="val loss")
plt.scatter(vts, vresiduals, alpha=0.5, color="pink", label="val")
plt.xlim(.5,14)
plt.ylim(-20,10)
plt.legend()
plt.show()

plt.plot(es)
plt.show()
plt.plot(ves)
plt.title(label="val")
#plt.title("errors for preceding graph \n")
plt.show()

plt.scatter(vts, vts, color="red", alpha=0.5)
#plt.scatter(vps, vps, color="red", alpha=0.2)
plt.scatter(vts, vps, color="black", alpha=0.2)
plt.plot(range(1,13),range(1,13))
plt.xlim(.5,14)
plt.ylim(.5,14)
plt.xlabel("targets (mostly pypka, less than 44 (IIIRC) of 800+ targets are fake)")
plt.show()
#plt.title("lr 0.01 400 epochs dim2 depth 3 from 2 to end bc immediatelz went down")

# %%
#pred = sum(torch.sum(output[0],dim=-2))
plt.plot(list(torch.mean(y[0],dim=1)))
#plt.plot(list(torch.sum(output[0],dim=-2)))
pred
sample
#updATE
# Out:
# 'TYR152A'

# %%
torch.sum(torch.abs((torch.mean(y[0],dim=1))))
#torch.min(torch.mean(y[0],dim=1))
# Out:
# tensor(5.4597, grad_fn=<SumBackward0>)

# %%
sum(sum(y))
# Out:
# tensor([-4.7768,  0.4321], grad_fn=<AddBackward0>)

# %% [markdown]
# label
# att

# %%
output
# Out:
# tensor([[[ 1.1496e-01,  1.0391e-01,  1.1783e-01,  1.6433e-01, -1.6158e-01,
#            8.9522e-02, -8.1926e-02,  2.2535e-03, -1.8889e-01,  1.5831e-02,
#           -1.4571e-01, -2.7045e-01, -1.8320e-01,  1.4009e-01, -1.4963e-01,
#           -7.6368e-02, -6.1635e-02,  2.0117e-02,  7.4543e-03, -1.1037e-01,
#           -8.6615e-04, -1.1765e-01],
#          [ 8.0207e-02,  9.7228e-02,  1.8719e-01,  2.2441e-01, -2.2072e-01,
#            1.0151e-01, -5.9836e-02, -1.6999e-02, -1.7114e-01,  7.9111e-02,
#           -1.5173e-01, -3.6523e-01, -2.6459e-01,  1.1497e-01, -2.0310e-01,
#           -4.4643e-02, -7.9572e-02, -1.1103e-02, -1.5391e-02, -1.3758e-01,
#           -5.4938e-03, -1.7942e-01]],
#
#         [[-4.0881e-03,  5.8974e-02,  1.1613e-01,  2.6422e-01, -6.6653e-02,
#            8.9053e-02, -2.6279e-02,  1.4548e-01, -8.4164e-02, -1.2148e-01,
#           -1.2242e-01, -3.0125e-01, -1.5687e-01,  9.7183e-02, -1.7681e-01,
#            1.7768e-02, -4.6786e-02,  5.9820e-02, -3.7417e-02, -4.6691e-02,
#           -1.2793e-01, -1.0874e-01],
#          [-1.1516e-01,  4.7129e-02,  1.0935e-01,  3.9797e-01, -1.1859e-02,
#            3.5724e-02,  8.4506e-02,  2.3810e-01,  9.0729e-03, -2.2680e-01,
#           -1.7015e-01, -3.3593e-01, -2.3660e-01,  5.3985e-02, -2.5095e-01,
#            9.2066e-02, -1.8805e-02,  4.6477e-02, -8.5002e-02, -3.1738e-03,
#           -2.2128e-01, -1.5686e-01]],
#
#         [[ 9.8784e-02,  9.4358e-02,  1.1012e-01,  1.7638e-01, -1.4031e-01,
#            9.1653e-02, -7.5072e-02,  3.0926e-02, -1.6626e-01, -1.6091e-02,
#           -1.4017e-01, -2.6878e-01, -1.6764e-01,  1.3508e-01, -1.5014e-01,
#           -6.3893e-02, -5.0188e-02,  2.7371e-02,  4.5573e-03, -9.7881e-02,
#           -1.3889e-01, -2.7229e-01, -1.7191e-01,  1.3658e-01, -1.4477e-01,
#           -7.0162e-02, -5.6337e-02,  3.3008e-02,  3.2218e-03, -1.0788e-01,
#           -1.5750e-02, -1.1248e-01],
#          [-8.2071e-02,  5.8765e-02,  1.1632e-01,  3.6459e-01, -4.5074e-02,
#            3.9709e-02,  7.0850e-02,  1.8944e-01, -2.6453e-02, -1.8233e-01,
#           -1.6263e-01, -3.3392e-01, -2.3653e-01,  5.4027e-02, -2.3684e-01,
#            7.7961e-02, -2.1039e-02,  3.7276e-02, -7.8860e-02, -2.3447e-02,
#           -1.8215e-01, -1.5881e-01]]], grad_fn=<AddBackward0>)

# %%
output[0].detach().numpy()
att = [o[0][0].item() for o in output]
plt.plot(att)
plt.title(f"{pred} ~ attention({sample} m2_out) \n label={label}")
sum(att)
#np.sum(att)
plt.show()
#plt.plot(list(y[0][:,0]))
#plt.plot(list(y[0][:,1]))
plt.plot(list(y[0][:,0] * y[0][:,1]))
plt.title(f"{sample} m2out columns multiplied")

#plt.plot(list(torch.mean(y,dim=0)))
torch.matmul(torch.tensor(y[0][:,0] * y[0][:,1]),torch.tensor(att))
torch.matmul(torch.tensor(y[0][:,0] * y[0][:,1]),torch.tensor(att))
# Out:
# /home/jrhoernschemeyer/.local/lib/python3.6/site-packages/ipykernel_launcher.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#
# /home/jrhoernschemeyer/.local/lib/python3.6/site-packages/ipykernel_launcher.py:15: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   from ipykernel import kernelapp as app
# tensor(-0.1704)

# %%
torch.mean(10 ** y[0])
# Out:
# tensor(1.4091, grad_fn=<MeanBackward0>)

# %%
import torch
import torch.nn as nn

class SimpleMultiheadAttention(nn.Module):
    def __init__(self, embed_dim, num_heads):
        super(SimpleMultiheadAttention, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(embed_dim, num_heads)
    
    def forward(self, x):
        """
        x: Tensor of shape (seq_length, batch_size, embed_dim)
        """
        # In self-attention, query, key, and value are all the same.
        attn_outputs, attn_weights = self.multihead_attn(x, x, x)
        return attn_outputs#, attn_weights

# Example usage:


# Create a random tensor in the expected shape: (seq_length, batch_size, embed_dim)
z = torch.randn(22, 1, 2) #nnodes, 1, dim

#figure out attention scores for ea<
# ch part of the input and then combine them.
#so can multiply together amino acids of entire protein, or e.g. the dimensions
#used as output.
print(y[0].shape)
x=y[0].unsqueeze(2)
print(x.shape)
#print(z)

#mha = SimpleMultiheadAttention(22, 1)
output= mha(PositionalEncoding(22)(x))
print("Multihead Attention Output Shape:", output.shape)   # (5, 2, 16)
print("Multihead Attention Weights Shape:", weights.shape)   # (2*num_heads, 5, 5)
print(weights)
#torch.log(torch.abs(sum(
a = torch.sum(output[0],dim=-2)
print(len(torch.sum(output[0],dim=0)))
torch.log(7+(torch.abs(torch.sum(torch.sum(output[0],dim=-2)))))
# Out:
# torch.Size([15, 2])
# torch.Size([15, 2, 1])
# Multihead Attention Output Shape: torch.Size([15, 2, 22])
# Multihead Attention Weights Shape: torch.Size([1, 15, 15])
# tensor([[[1.3033e-07, 2.3046e-07, 1.5368e-07, 1.5950e-06, 2.0091e-07,
#           1.7502e-06, 2.6333e-06, 3.1753e-07, 9.9999e-01, 7.1756e-07,
#           2.0194e-07, 1.8953e-07, 2.6484e-07, 3.7125e-07, 1.2543e-07],
#          [1.1914e-28, 2.1591e-28, 1.2770e-28, 2.3214e-26, 2.4838e-28,
#           2.1664e-27, 2.9677e-27, 3.9180e-28, 1.0000e+00, 2.5882e-27,
#           1.3767e-28, 1.5582e-28, 2.7771e-28, 5.0405e-28, 5.2851e-29],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [3.6501e-41, 1.0987e-40, 2.2552e-40, 1.6854e-36, 1.8226e-40,
#           2.0444e-36, 8.5448e-38, 5.2206e-40, 1.0000e+00, 4.4285e-39,
#           5.2766e-41, 8.6344e-41, 1.2456e-40, 1.8074e-39, 2.3002e-41],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 1.6297e-42, 0.0000e+00,
#           4.3721e-43, 1.6381e-42, 1.4013e-45, 1.0000e+00, 2.9427e-44,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.4013e-45, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [2.6389e-13, 5.5742e-13, 5.7823e-13, 1.3942e-11, 6.4830e-13,
#           1.6458e-11, 1.0508e-11, 5.7414e-13, 1.0000e+00, 2.3203e-12,
#           4.2802e-13, 4.0282e-13, 4.9578e-13, 1.2852e-12, 2.6609e-13],
#          [1.4768e-25, 2.6082e-25, 3.2399e-25, 7.1901e-23, 3.3604e-25,
#           3.6301e-23, 3.5282e-23, 7.7373e-25, 1.0000e+00, 3.9489e-24,
#           2.1009e-25, 2.4934e-25, 3.7569e-25, 1.2829e-24, 1.3341e-25],
#          [1.0932e-33, 3.0131e-33, 2.8191e-33, 3.6362e-30, 3.0719e-33,
#           3.0874e-30, 7.5808e-31, 1.1124e-32, 1.0000e+00, 7.7635e-32,
#           1.9516e-33, 2.5085e-33, 4.1149e-33, 1.7679e-32, 7.4652e-34],
#          [0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#           0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00],
#          [1.1548e-11, 1.6312e-11, 1.5490e-11, 3.2336e-10, 1.4494e-11,
#           8.9986e-11, 8.9983e-11, 2.4081e-11, 1.0000e+00, 3.1884e-11,
#           1.1586e-11, 1.2686e-11, 1.4573e-11, 3.5029e-11, 9.2929e-12]]],
#        grad_fn=<DivBackward0>)
# 22
# tensor(2.5937, grad_fn=<LogBackward0>)

# %%
label
# Out:
# 3.09459

# %% [markdown]
# x

# %%
x
# Out:
# tensor([[[4.6209e-02]],
#
#         [[8.8309e-01]],
#
#         [[2.7101e+00]],
#
#         [[7.5548e+00]],
#
#         [[1.0840e+00]],
#
#         [[1.0394e+01]],
#
#         [[7.3651e+00]],
#
#         [[2.4021e+00]],
#
#         [[6.5257e+01]],
#
#         [[3.4737e+00]],
#
#         [[6.4224e-01]],
#
#         [[8.1744e-01]],
#
#         [[1.2052e+00]],
#
#         [[3.3179e+00]],
#
#         [[3.2686e-01]]], grad_fn=<UnsqueezeBackward0>)

# %%
output
# Out:
# tensor([[[ -4.1536, -31.3089, -16.4627, -11.2560,  -8.4730,  32.0738, -19.2003,
#            -1.1521,   4.9170, -37.4337,  10.4717,  41.0693,  18.8291,  -8.0370,
#            46.4629, -29.1576,   5.8320,  51.1178, -39.4162,  36.3856,  -6.4433,
#            14.3187]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188]],
#
#         [[ -4.1537, -31.3092, -16.4628, -11.2560,  -8.4731,  32.0741, -19.2005,
#            -1.1520,   4.9171, -37.4340,  10.4718,  41.0696,  18.8293,  -8.0371,
#            46.4633, -29.1579,   5.8320,  51.1182, -39.4165,  36.3859,  -6.4433,
#            14.3188
#            0.0000,  1.8518,  2.5626,  1.6580,  2.6072,  1.5722,  2.6156,
#            1.5350,  2.6172,  1.5188,  2.6175,  1.5118,  2.6176,  1.5088,
#            2.6176]],
#
#         [[18.8595, 18.5316, 18.4336, 19.0481, 20.5244, 19.1324, 20.2696,
#           20.2291, 19.8461, 20.5073, 19.6322, 20.5622, 19.5370, 20.5727,
#           19.4956, 20.5746, 19.4776, 20.5750, 19.4699, 20.5750, 19.4665,
#           20.5751]],
#
#         [[ 8.9600, 10.0760,  8.9614, 10.1258, 11.0513,  0.0000, 10.9361,
#           10.7685, 10.4897, 11.1004, 10.2560, 11.1667, 10.1515, 11.1793,
#           10.1059, 11.1817, 10.0862, 11.1821, 10.0776, 11.1822, 10.0739,
#           11.1822]],
#
#         [[76.0095, 77.5433, 75.6212, 77.1209, 77.4712, 75.9089,  0.0000,
#            0.0000, 77.0601, 77.6196, 76.8072, 77.6984, 76.6933, 77.7133,
#           76.6437, 77.7161,  0.0000, 77.7167, 76.6128, 77.7168, 76.6088,
#            0.0000]],
#
#         [[34.9057, 35.4471, 33.7613, 35.3195, 35.1594, 33.5931, 35.4051,
#           34.9874, 34.9286, 35.4362, 34.6570,  0.0000,  0.0000, 35.5459,
#           34.4800, 35.5492, 34.4566, 35.5498, 34.4466, 35.5499, 34.4422,
#           35.5499]],
#
#         [[ 0.0000,  0.0000,  6.1362,  7.4655,  6.9323,  5.4167,  7.3894,
#            6.8503,  6.9063,  7.3614,  6.6165,  7.4679,  6.4841,  7.4883,
#            6.4262,  7.4921,  6.4011,  7.4928,  0.0000,  7.4930,  6.3855,
#            7.4930]],
#
#         [[ 3.4833,  1.9166,  2.9923,  3.8474,  3.1217,  1.7099,  3.8029,
#            3.1460,  3.3192,  3.7213,  3.0118,  3.8431,  2.8702,  3.8664,
#            2.8082,  3.8708,  2.7813,  3.8716,  2.7696,  3.8718,  0.0000,
#            3.8718]],
#
#         [[ 0.8415,  0.0974,  1.8275,  2.0508,  1.3203,  0.0000,  2.2314,
#            1.4610,  1.7533,  2.1018,  1.4290,  2.2399,  1.2782,  2.2664,
#            1.2121,  0.0000,  1.1834,  2.2723,  1.1709,  2.2725,  1.1655,
#            2.2725]],
#
#         [[ 0.0000,  7.7920,  9.0754,  0.0000,  8.0490,  6.9877,  9.1884,
#            8.3096,  0.0000,  9.0167,  8.3816,  9.1719,  8.2217,  0.0000,
#            0.0000,  9.2075,  8.1210,  9.2086,  0.0000,  9.2088,  8.1021,
#            9.2088]],
#
#         [[ 0.6843,  0.0000,  2.6277,  0.0000,  1.2641,  0.4373,  2.6231,
#            1.6416,  2.1752,  0.0000,  1.8190,  2.5886,  1.6501,  2.6221,
#            1.5757,  2.6284,  1.5434,  2.6296,  1.5295,  2.6298,  1.5234,
#            0.0000]],
#
#         [[ 7.2655,  8.1975,  8.1346,  6.6964,  6.6472,  6.0838,  8.2095,
#            7.1319,  7.7864,  7.9718,  7.4154,  8.1640,  7.2375,  0.0000,
#            7.1590,  8.2084,  7.1249,  8.2097,  7.1102,  8.2100,  7.1038,
#            8.2100]],
#
#         [[ 0.0000,  0.0000, 18.7508,  0.0000, 17.3466, 17.0663, 19.0892,
#           17.9224, 18.6972, 18.8278, 18.3121, 19.0397, 18.1253,  0.0000,
#           18.0428, 19.0889, 18.0069, 19.0903, 17.9914, 19.0906, 17.9847,
#           19.0906]],
#
#         [[ 0.0000,  2.4573,  3.4305,  2.0163,  2.2739,  2.2865,  4.1672,
#            0.0000,  3.8129,  3.8884,  3.4145,  4.1209,  3.2189,  4.1664,
#            0.0000,  4.1750,  3.0946,  4.1766,  3.0783,  4.1769,  3.0713,
#            0.0000]]], grad_fn=<MulBackward0>)

# %%
att
# Out:
# [8.521376609802246,
#  8.616423606872559,
#  3.596177101135254,
#  8.692103385925293,
#  8.690157890319824,
#  8.692734718322754,
#  8.692829132080078,
#  8.692830085754395,
#  5.876502990722656,
#  8.692819595336914,
#  8.692826271057129,
#  7.386716365814209,
#  8.692830085754395,
#  8.692830085754395,
#  8.683379173278809,
#  8.69206714630127,
#  8.692830085754395,
#  8.692830085754395,
#  8.692819595336914,
#  8.692830085754395,
#  8.517755508422852,
#  8.664810180664062]

# %%
y[0].shape

b=PositionalEncoding(54)
b(y[0].unsqueeze)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1011-08875150504a> in <module>
#       2
#       3 b=PositionalEncoding(54)
# ----> 4 b(y[0].unsqueeze(54))
#
# IndexError: Dimension out of range (expected to be in range of [-3, 2], but got 54)

# %%
#old_model = pnet #this one trained on bad labels

# %%
import torch
import torch.nn as nn

class SimpleMultiheadAttention(nn.Module):
    def __init__(self, embed_dim, num_heads):
        super(SimpleMultiheadAttention, self).__init__()
        self.multihead_attn = nn.MultiheadAttention(embed_dim, num_heads)
    
    def forward(self, x):
        """
        x: Tensor of shape (seq_length, batch_size, embed_dim)
        """
        # In self-attention, query, key, and value are all the same.
        attn_output, attn_weights = self.multihead_attn(x, x, x)
        return attn_output, attn_weights

# Example usage:
batch_size = 2
seq_length = 5
embed_dim = 16
num_heads = 4

# Create a random tensor in the expected shape: (seq_length, batch_size, embed_dim)
x = torch.randn(seq_length, batch_size, embed_dim)
mha = SimpleMultiheadAttention(embed_dim, num_heads)
output, weights = mha(x)
print("Multihead Attention Output Shape:", output.shape)   # (5, 2, 16)
print("Multihead Attention Weights Shape:", weights.shape)   # (2*num_heads, 5, 5)
# Out:
# array([-0.0298245])

# %%
# Out:
# Text(0.5, 1.0, 'lr 0.01 400 epochs dim2 depth 3 from 2 to end bc immediatelz went down')

# %%
plt.scatter(ts, ps, alpha=0.5)

# %%
len(Ds.keys())
#Fails = fails
for i,j in fails.items():
    print(len(j))
for a in results.values():
    print(len(a))
# Out:
# 20

# %%
len(all_data["10gs"]["pos"])
# Out:
# 106

# %%
Ds.keys()
# Out:
# dict_keys(['10gs', '109l', '111m', '110m', '108m', '110l', '109m', '111l', '108l', '104m', '106m', '105m', '103m', '107m', '107l', '103l', '102m', '102l', '101m', '104l'])

# %%
a=[]
for i in range(20):
    print(([(k[4], k[1][:3]) for k in results[i] ]))
    
    print(np.mean([k[4] for k in results[i] ]))
    #a.append(k[4] for k in results[i])


print(a)
